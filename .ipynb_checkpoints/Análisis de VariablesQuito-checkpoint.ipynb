# %% [markdown]
# # Análisis univariado y multivariado

# %% [markdown]
# Se usarán las siguientes variables para el análisis:
# * **FECHA_INICIO_ACTIVIDADES:** Muestra el inicio de actividades del contribuyente, para el análisis se pueden establecer periodos (presidenciales, municipales, etc) y obtener una relación entre aquel y la cantidad de nuevos negocios.
# * **FECHA_SUSPENSION_DEFINITIVA:** Fechas en las que un negocio dejó de operar. El análisis de esta variable nos ayudará a determinar en qué periodo temporal desaparecieron negocios, con lo que podremos analizar las medidas económicas tomadas por las instituciones alrededor de aquel periodo
# * **ACTIVIDAD_ECONOMICA:** Define el tipo de actividad que el contribuyente ejerce. Con esta variable podemos generar grupos y poder profundizar el análisis
# * **NUMERO_ESTABLECIMIENTO:** Número secuencial. Permite  conocer  el  orden  cronológico  de  la  creación  de los establecimientos.

# %%
import csv  # library csv
import pandas as pd  # library pandas
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
FILE_NAME = 'Proyecto/QUITO.csv'
COLOR = "tan"

# %%
guayaquil = pd.read_csv(FILE_NAME, sep=',', encoding='utf-8', error_bad_lines=False, index_col=0)  # reading GUAYAQUIL file
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
guayaquil.columns
# Out:
# Index(['NUMERO_RUC', 'RAZON_SOCIAL', 'NOMBRE_COMERCIAL',
#        'ESTADO_CONTRIBUYENTE', 'CLASE_CONTRIBUYENTE',
#        'FECHA_INICIO_ACTIVIDADES', 'FECHA_ACTUALIZACION',
#        'FECHA_SUSPENSION_DEFINITIVA', 'FECHA_REINICIO_ACTIVIDADES', 'OBLIGADO',
#        'TIPO_CONTRIBUYENTE', 'NUMERO_ESTABLECIMIENTO',
#        'NOMBRE_FANTASIA_COMERCIAL', 'CALLE', 'NUMERO', 'INTERSECCION',
#        'ESTADO_ESTABLECIMIENTO', 'DESCRIPCION_PROVINCIA', 'DESCRIPCION_CANTON',
#        'DESCRIPCION_PARROQUIA', 'CODIGO_CIIU', 'ACTIVIDAD_ECONOMICA'],
#       dtype='object')

# %%
df = guayaquil.dropna(subset=['FECHA_INICIO_ACTIVIDADES'])

# %%
df.head()
# Out:
#       NUMERO_RUC                     RAZON_SOCIAL NOMBRE_COMERCIAL  \
# ID
# 1   100092519001  BAYANCELA GONZALEZ HUGO ENRIQUE              NaN
# 2   100121268001     LUCERO VELEZ MANUEL SALVADOR              NaN
# 3   100122753001   AGUILERA TORAL MIGUEL PATRICIO              NaN
# 4   100122753001   AGUILERA TORAL MIGUEL PATRICIO              NaN
# 5   100122753001   AGUILERA TORAL MIGUEL PATRICIO              NaN
#
#    ESTADO_CONTRIBUYENTE CLASE_CONTRIBUYENTE FECHA_INICIO_ACTIVIDADES  \
# ID
# 1                PASIVO               OTROS               20/11/1973
# 2            SUSPENDIDO               OTROS               30/04/1998
# 3                ACTIVO               OTROS               28/06/1985
# 4                ACTIVO               OTROS               28/06/1985
# 5                ACTIVO               OTROS               28/06/1985
#
#    FECHA_ACTUALIZACION FECHA_SUSPENSION_DEFINITIVA FECHA_REINICIO_ACTIVIDADES  \
# ID
# 1           29/05/2008                  29/09/2009                        NaN
# 2           09/07/2009                  31/08/2011                        NaN
# 3           17/07/2017                         NaN                        NaN
# 4           17/07/2017                         NaN                        NaN
# 5           17/07/2017                         NaN                        NaN
#
#    OBLIGADO  ... NOMBRE_FANTASIA_COMERCIAL                      CALLE NUMERO  \
# ID           ...
# 1         N  ...                       NaN                    BOLIVIA   1300
# 2         N  ...                       NaN                    29 AVA.   4805
# 3         S  ...     ELECTRONICA LOS ANDES              AV EL BOMBERO    S/N
# 4         S  ...     ELECTRONICA LOS ANDES        AV BENJAMIN CARRION    S/N
# 5         S  ...     ELECTRONICA LOS ANDES  AV CARLOS JULIO AROSEMENA    S/N
#
#          INTERSECCION ESTADO_ESTABLECIMIENTO DESCRIPCION_PROVINCIA  \
# ID
# 1                 NaN                    CER                GUAYAS
# 2   CALLE O - CALLE P                    CER                GUAYAS
# 3                 S/N                    CER                GUAYAS
# 4             TERCERA                    CER                GUAYAS
# 5                 S/N                    CER                GUAYAS
#
#    DESCRIPCION_CANTON DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 1           GUAYAQUIL         GARCIA MORENO     Q862001
# 2           GUAYAQUIL        FEBRES CORDERO     H492101
# 3           GUAYAQUIL                TARQUI     G469000
# 4           GUAYAQUIL                TARQUI     G469000
# 5           GUAYAQUIL                TARQUI     G469000
#
#                                   ACTIVIDAD_ECONOMICA
# ID
# 1   CONSULTA Y TRATAMIENTO POR MÉDICOS GENERALES Y...
# 2   TRANSPORTE TERRESTRE DE PASAJEROS POR SISTEMAS...
# 3   VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...
# 4   VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...
# 5   VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...
#
# [5 rows x 22 columns]

# %%
df['FECHA_INICIO_ACTIVIDADES'] = pd.to_datetime(df['FECHA_INICIO_ACTIVIDADES'])
df['fecha_ano'] = df['FECHA_INICIO_ACTIVIDADES'].dt.year
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# solo consideramos para nuestro analisis desde 1998
df_anos = df[ (1998 <=df['fecha_ano']) & (df['fecha_ano']<=2018) ]

# %% [markdown]
# ## total de contribuyentes por año desde 1998 hasta 2018

# %%
# total de contribuyente para este analisis
total = float(len(df_anos))
total
# Out:
# 792193.0

# %%
tabla_x_ano = df_anos.groupby("fecha_ano").count()
tabla_x_ano["NUMERO_RUC"]
# Out:
# fecha_ano
# 1998    19342
# 1999    35575
# 2000    35353
# 2001    31316
# 2002    45515
# 2003    30886
# 2004    32167
# 2005    36310
# 2006    35801
# 2007    35994
# 2008    46410
# 2009    44846
# 2010    44890
# 2011    40511
# 2012    43271
# 2013    42311
# 2014    40199
# 2015    33542
# 2016    32705
# 2017    35964
# 2018    49285
# Name: NUMERO_RUC, dtype: int64

# %%
#nuevos contribuyentes
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='fecha_ano', data=df_anos,color=COLOR)
ax.set(ylabel='CANTIDAD DE NUEVOS CONTRIBUYENTES', xlabel="AÑO",title='Nuevos Contribuyentes por año')
total = float(len(df_anos))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f} %'.format((height/total) * 100),
            ha="center")

# %%
#contribuyentes por año deacuerdo a su estado
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='fecha_ano', data=df_anos, hue="ESTADO_CONTRIBUYENTE",palette=sns.color_palette("Set1", n_colors=3, desat=.5))
ax.set(ylabel='CANTIDAD DE CONTRIBUYENTES', xlabel="AÑO",title='Contribuyentes por año categorizados por el respectivo estado actual del contribuyente')
total = float(len(df_anos))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f} %'.format((height/total) * 100),
            ha="center")

# %%
plt.figure(figsize=(16, 6))
ax = sns.catplot(x="fecha_ano", data=df_anos, color=COLOR,row="ESTADO_CONTRIBUYENTE",kind="count",height=5, aspect=4)
total = float(len(df_anos))

# %%
def por_mes(ano):
    plt.figure(figsize=(16, 6))
    df_x = df_anos[df_anos['fecha_ano']==ano ]
    ax = sns.countplot(x='fecha_mes', data=df_x,color=COLOR,order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"])
    ax.set(ylabel='CANTIDAD DE NUEVOS CONTRIBUYENTES', xlabel="MES",title='Nuevos Contribuyentes ' + str(ano),ylim=(0, 10500))
    total = float(len(df_x))
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
        height + 3,
        '{:1.2f} %'.format((height/total) * 100),
        ha="center")
    plt.savefig("CONTRIBUYENTES_X_MES_"+str(ano)+".png")
def mapper(month):
    return month.strftime('%b') 
df_anos['fecha_mes'] = df_anos['FECHA_INICIO_ACTIVIDADES'].apply(mapper)
for ano in df_anos['fecha_ano'].unique().tolist():
    por_mes(ano)
#convert -delay 30 *.png animated_chart.gif
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
poblacion_x = pd.read_csv("Proyecto/factorNormalizacionGUAYAQUIL.csv" ,sep=",",encoding ="utf-8",error_bad_lines=False)
poblacion_x
# Out:
#           DESCRIPCION_PARROQUIA  POBLACION     AREA     FACTOR  TOTAL_LOCALES
# 0                     GUAYAQUIL  2291158.0  2493.86   0.008343          19114
# 1   JUAN GÓMEZ RENDÓN(PROGRESO)    11897.0   326.45   0.154661           1840
# 2                         MORRO     5019.0   270.12   0.155011            778
# 3                       POSORJA    24136.0    73.18   0.207698           5013
# 4                          PUNA     6769.0   894.64   0.268134           1815
# 5                       TENGUEL    11936.0   138.12   0.210288           2510
# 6                      AYACUCHO    10706.0      NaN   1.293293          13846
# 7                FEBRES CORDERO   343836.0      NaN   0.317518         109174
# 8                 GARCIA MORENO    50028.0      NaN   0.511314          25580
# 9                     LETAMENDI    95943.0      NaN   0.328862          31552
# 10                        SUCRE    11952.0      NaN   0.944612          11290
# 11                     URDANETA    22680.0      NaN   0.561772          12741
# 12             NUEVE DE OCTUBRE     5747.0      NaN   2.384026          13701
# 13           BOLIVAR (SAGRARIO)     6758.0      NaN   1.159811           7838
# 14           OLMEDO (SAN ALEJO)     6623.0      NaN   3.514872          23279
# 15           CARBO (CONCEPCION)     1383.0      NaN  16.966739          23465
# 16                         ROCA     5545.0      NaN   2.089450          11586
# 17                   ROCAFUERTE     2062.0      NaN  18.296799          37728
# 18                       TARQUI  1050826.0      NaN   0.412968         433958
# 19                       XIMENA   546254.0      NaN   0.316113         172678
# 20                    PASCUALES    74932.0      NaN   0.435915          32664

# %%
def por_ano_parroquia(ano):
    df_x = df_anos[df_anos['fecha_ano']==ano]
    df_x_parroquia = df_x.groupby(["DESCRIPCION_PARROQUIA"]).count().reset_index()
    df_x_parroquia = df_x_parroquia[["DESCRIPCION_PARROQUIA","NUMERO_RUC"]]
    resultado = pd.merge(left=df_x_parroquia,right=poblacion_x, left_on='DESCRIPCION_PARROQUIA', right_on='DESCRIPCION_PARROQUIA',suffixes=("",""))
    resultado["cantidadNormalizada"] = resultado["NUMERO_RUC"] * resultado["FACTOR"]
    print(resultado["cantidadNormalizada"].max())
    resultado = resultado[["DESCRIPCION_PARROQUIA","cantidadNormalizada"]]
    resultado.to_csv("parroquias_"+str(ano)+".csv", header=True, encoding="utf-8", index=False)
for ano in df_anos['fecha_ano'].unique().tolist():
    por_ano_parroquia(ano)
#convert -delay 30 *.png animated_chart.gif
df_parroquias
# Out:
# 15954.808923375365
# 30775.216294859365
# 28634.490785645008
# 22925.88942774006
# 28817.458777885553
# 22358.68865179438
# 22742.921435499517
# 22084.236663433563
# 23804.135790494667
# 17345.365664403493
# 17089.210475266733
# 14655.736178467509
# 15607.169738118333
# 9843.677982541223
# 7428.500484966054
# 13228.585838991272
# 12020.997090203688
# 7446.797284190107
# 11892.919495635308
# 8361.637245392823
# 10520.659553831232
#          NUMERO_RUC  RAZON_SOCIAL  NOMBRE_COMERCIAL  ESTADO_CONTRIBUYENTE  \
# ID
# 2              2279          2279               304                  2279
# 11            15590         15590              2075                 15590
# 18             1201          1201               168                  1201
# 19             1201          1201               168                  1201
# 20            15590         15590              2075                 15590
# 21            15590         15590              2075                 15590
# 28            15590         15590              2075                 15590
# 30            21362         21362              1987                 21362
# 34             8645          8645               424                  8645
# 35            21362         21362              1987                 21362
# 45             3475          3475               115                  3475
# 46             1201          1201               168                  1201
# 53              959           959                69                   959
# 60             3024          3024               444                  3024
# 62              484           484                52                   484
# 63             1006          1006               149                  1006
# 64              478           478                36                   478
# 65            15590         15590              2075                 15590
# 66            16095         16095              2308                 16095
# 70               83            83                 4                    83
# 75            21362         21362              1987                 21362
# 82             5588          5588               271                  5588
# 85             3337          3337               124                  3337
# 86             1222          1222               153                  1222
# 87             3337          3337               124                  3337
# 90            16095         16095              2308                 16095
# 92            15590         15590              2075                 15590
# 98             3704          3704               568                  3704
# 99             3704          3704               568                  3704
# 102           15252         15252              1534                 15252
# ...             ...           ...               ...                   ...
# 1341539        8860          8860               309                  8860
# 1341540       22209         22209              1226                 22209
# 1341542       22209         22209              1226                 22209
# 1341546       16272         16272              1218                 16272
# 1341575        8860          8860               309                  8860
# 1341579       22209         22209              1226                 22209
# 1341581       22209         22209              1226                 22209
# 1341583        3987          3987               183                  3987
# 1341584        3987          3987               183                  3987
# 1341585        3248          3248               154                  3248
# 1341586         262           262                28                   262
# 1341587       22209         22209              1226                 22209
# 1341588       16272         16272              1218                 16272
# 1341589       22209         22209              1226                 22209
# 1341590        5975          5975               692                  5975
# 1341592       22209         22209              1226                 22209
# 1341597        4956          4956               189                  4956
# 1341600       22209         22209              1226                 22209
# 1341601       22209         22209              1226                 22209
# 1341602       16272         16272              1218                 16272
# 1341603        1863          1863               956                  1863
# 1341604        1863          1863               956                  1863
# 1341618        4956          4956               189                  4956
# 1341626        1925          1925               126                  1925
# 1341629        8860          8860               309                  8860
# 1341631       19765         19765              1603                 19765
# 1341634         411           411                18                   411
# 1341637         426           426                14                   426
# 1341641        8860          8860               309                  8860
# 1341642       22209         22209              1226                 22209
#
#          CLASE_CONTRIBUYENTE  FECHA_INICIO_ACTIVIDADES  FECHA_ACTUALIZACION  \
# ID
# 2                       2279                      2279                 1796
# 11                     15590                     15590                14722
# 18                      1201                      1201                 1128
# 19                      1201                      1201                 1128
# 20                     15590                     15590                14722
# 21                     15590                     15590                14722
# 28                     15590                     15590                14722
# 30                     21362                     21362                17690
# 34                      8645                      8645                 6600
# 35                     21362                     21362                17690
# 45                      3475                      3475                 2393
# 46                      1201                      1201                 1128
# 53                       959                       959                  484
# 60                      3024                      3024                 2559
# 62                       484                       484                  365
# 63                      1006                      1006                  875
# 64                       478                       478                  391
# 65                     15590                     15590                14722
# 66                     16095                     16095                13925
# 70                        83                        83                   54
# 75                     21362                     21362                17690
# 82                      5588                      5588                 4031
# 85                      3337                      3337                 2356
# 86                      1222                      1222                  973
# 87                      3337                      3337                 2356
# 90                     16095                     16095                13925
# 92                     15590                     15590                14722
# 98                      3704                      3704                 3288
# 99                      3704                      3704                 3288
# 102                    15252                     15252                12265
# ...                      ...                       ...                  ...
# 1341539                 8860                      8860                 1847
# 1341540                22209                     22209                 5201
# 1341542                22209                     22209                 5201
# 1341546                16272                     16272                 6093
# 1341575                 8860                      8860                 1847
# 1341579                22209                     22209                 5201
# 1341581                22209                     22209                 5201
# 1341583                 3987                      3987                 1221
# 1341584                 3987                      3987                 1221
# 1341585                 3248                      3248                  699
# 1341586                  262                       262                   75
# 1341587                22209                     22209                 5201
# 1341588                16272                     16272                 6093
# 1341589                22209                     22209                 5201
# 1341590                 5975                      5975                 4867
# 1341592                22209                     22209                 5201
# 1341597                 4956                      4956                 1080
# 1341600                22209                     22209                 5201
# 1341601                22209                     22209                 5201
# 1341602                16272                     16272                 6093
# 1341603                 1863                      1863                 1009
# 1341604                 1863                      1863                 1009
# 1341618                 4956                      4956                 1080
# 1341626                 1925                      1925                  805
# 1341629                 8860                      8860                 1847
# 1341631                19765                     19765                11387
# 1341634                  411                       411                  105
# 1341637                  426                       426                   53
# 1341641                 8860                      8860                 1847
# 1341642                22209                     22209                 5201
#
#          FECHA_SUSPENSION_DEFINITIVA  FECHA_REINICIO_ACTIVIDADES  OBLIGADO  \
# ID
# 2                               1533                         665      2279
# 11                              7672                        4762     15590
# 18                               685                         337      1201
# 19                               685                         337      1201
# 20                              7672                        4762     15590
# 21                              7672                        4762     15590
# 28                              7672                        4762     15590
# 30                             11855                        7739     21362
# 34                              5622                        2829      8645
# 35                             11855                        7739     21362
# 45                              2482                         990      3475
# 46                               685                         337      1201
# 53                                58                          52       959
# 60                              1798                         898      3024
# 62                               222                          92       484
# 63                               683                         280      1006
# 64                               309                         151       478
# 65                              7672                        4762     15590
# 66                              8456                        5125     16094
# 70                                61                          18        83
# 75                             11855                        7739     21362
# 82                              3755                        1598      5588
# 85                              2400                        1017      3337
# 86                               446                         216      1222
# 87                              2400                        1017      3337
# 90                              8456                        5125     16094
# 92                              7672                        4762     15590
# 98                              2541                        1160      3704
# 99                              2541                        1160      3704
# 102                             8108                        4248     15252
# ...                              ...                         ...       ...
# 1341539                         2531                         140      8860
# 1341540                         6735                         373     22209
# 1341542                         6735                         373     22209
# 1341546                         6867                        1023     16272
# 1341575                         2531                         140      8860
# 1341579                         6735                         373     22209
# 1341581                         6735                         373     22209
# 1341583                         2082                         228      3987
# 1341584                         2082                         228      3987
# 1341585                          773                          66      3248
# 1341586                           89                           3       262
# 1341587                         6735                         373     22209
# 1341588                         6867                        1023     16272
# 1341589                         6735                         373     22209
# 1341590                         3933                        1948      5975
# 1341592                         6735                         373     22209
# 1341597                         1280                          79      4956
# 1341600                         6735                         373     22209
# 1341601                         6735                         373     22209
# 1341602                         6867                        1023     16272
# 1341603                          277                          27      1863
# 1341604                          277                          27      1863
# 1341618                         1280                          79      4956
# 1341626                         1075                         184      1925
# 1341629                         2531                         140      8860
# 1341631                        12188                        3683     19765
# 1341634                          117                           6       411
# 1341637                          137                           6       426
# 1341641                         2531                         140      8860
# 1341642                         6735                         373     22209
#
#          ...  CALLE  NUMERO  INTERSECCION  ESTADO_ESTABLECIMIENTO  \
# ID       ...
# 2        ...   2242    2260          2216                    2279
# 11       ...   6141   15267          4252                   15590
# 18       ...   1193    1171          1150                    1201
# 19       ...   1193    1171          1150                    1201
# 20       ...   6141   15267          4252                   15590
# 21       ...   6141   15267          4252                   15590
# 28       ...   6141   15267          4252                   15590
# 30       ...   7019   20984          5345                   21362
# 34       ...   2599    8476          2065                    8645
# 35       ...   7019   20984          5345                   21362
# 45       ...   3371    3473          3354                    3475
# 46       ...   1193    1171          1150                    1201
# 53       ...    877     795           693                     959
# 60       ...   1265    3005           688                    3024
# 62       ...    481     484           477                     484
# 63       ...    989     991           974                    1006
# 64       ...    472     476           468                     478
# 65       ...   6141   15267          4252                   15590
# 66       ...   5395   15665          4111                   16095
# 70       ...     57      81            19                      83
# 75       ...   7019   20984          5345                   21362
# 82       ...   1225    5566          1012                    5588
# 85       ...   3212    3305          3186                    3337
# 86       ...   1212    1220          1194                    1222
# 87       ...   3212    3305          3186                    3337
# 90       ...   5395   15665          4111                   16095
# 92       ...   6141   15267          4252                   15590
# 98       ...   3613    3581          3576                    3704
# 99       ...   3613    3581          3576                    3704
# 102      ...   4724   15177          3557                   15252
# ...      ...    ...     ...           ...                     ...
# 1341539  ...   1425    8107           957                    8860
# 1341540  ...   3917   18811          2536                   22209
# 1341542  ...   3917   18811          2536                   22209
# 1341546  ...   3821   16084          2933                   16272
# 1341575  ...   1425    8107           957                    8860
# 1341579  ...   3917   18811          2536                   22209
# 1341581  ...   3917   18811          2536                   22209
# 1341583  ...   3688    3934          3343                    3987
# 1341584  ...   3688    3934          3343                    3987
# 1341585  ...    338    3113           209                    3248
# 1341586  ...    201     202           197                     262
# 1341587  ...   3917   18811          2536                   22209
# 1341588  ...   3821   16084          2933                   16272
# 1341589  ...   3917   18811          2536                   22209
# 1341590  ...   1608    5858          1364                    5975
# 1341592  ...   3917   18811          2536                   22209
# 1341597  ...   4344    4677          3855                    4956
# 1341600  ...   3917   18811          2536                   22209
# 1341601  ...   3917   18811          2536                   22209
# 1341602  ...   3821   16084          2933                   16272
# 1341603  ...   1554    1840          1516                    1863
# 1341604  ...   1554    1840          1516                    1863
# 1341618  ...   4344    4677          3855                    4956
# 1341626  ...    330    1908           262                    1925
# 1341629  ...   1425    8107           957                    8860
# 1341631  ...   4129   19680          3374                   19765
# 1341634  ...    361     365           344                     411
# 1341637  ...    133     393            82                     426
# 1341641  ...   1425    8107           957                    8860
# 1341642  ...   3917   18811          2536                   22209
#
#          DESCRIPCION_PROVINCIA  DESCRIPCION_CANTON  CODIGO_CIIU  \
# ID
# 2                         2279                2279         2279
# 11                       15590               15590        15590
# 18                        1201                1201         1201
# 19                        1201                1201         1201
# 20                       15590               15590        15590
# 21                       15590               15590        15590
# 28                       15590               15590        15590
# 30                       21362               21362        21362
# 34                        8645                8645         8645
# 35                       21362               21362        21362
# 45                        3475                3475         3475
# 46                        1201                1201         1201
# 53                         959                 959          959
# 60                        3024                3024         3024
# 62                         484                 484          484
# 63                        1006                1006         1006
# 64                         478                 478          478
# 65                       15590               15590        15590
# 66                       16095               16095        16095
# 70                          83                  83           83
# 75                       21362               21362        21362
# 82                        5588                5588         5588
# 85                        3337                3337         3337
# 86                        1222                1222         1222
# 87                        3337                3337         3337
# 90                       16095               16095        16095
# 92                       15590               15590        15590
# 98                        3704                3704         3704
# 99                        3704                3704         3704
# 102                      15252               15252        15252
# ...                        ...                 ...          ...
# 1341539                   8860                8860         8860
# 1341540                  22209               22209        22209
# 1341542                  22209               22209        22209
# 1341546                  16272               16272        16272
# 1341575                   8860                8860         8860
# 1341579                  22209               22209        22209
# 1341581                  22209               22209        22209
# 1341583                   3987                3987         3987
# 1341584                   3987                3987         3987
# 1341585                   3248                3248         3248
# 1341586                    262                 262          262
# 1341587                  22209               22209        22209
# 1341588                  16272               16272        16272
# 1341589                  22209               22209        22209
# 1341590                   5975                5975         5975
# 1341592                  22209               22209        22209
# 1341597                   4956                4956         4956
# 1341600                  22209               22209        22209
# 1341601                  22209               22209        22209
# 1341602                  16272               16272        16272
# 1341603                   1863                1863         1863
# 1341604                   1863                1863         1863
# 1341618                   4956                4956         4956
# 1341626                   1925                1925         1925
# 1341629                   8860                8860         8860
# 1341631                  19765               19765        19765
# 1341634                    411                 411          411
# 1341637                    426                 426          426
# 1341641                   8860                8860         8860
# 1341642                  22209               22209        22209
#
#          ACTIVIDAD_ECONOMICA  fecha_mes  cantidad
# ID
# 2                       2279       2279      2279
# 11                     15590      15590     15590
# 18                      1201       1201      1201
# 19                      1201       1201      1201
# 20                     15590      15590     15590
# 21                     15590      15590     15590
# 28                     15590      15590     15590
# 30                     21362      21362     21362
# 34                      8645       8645      8645
# 35                     21362      21362     21362
# 45                      3475       3475      3475
# 46                      1201       1201      1201
# 53                       959        959       959
# 60                      3024       3024      3024
# 62                       484        484       484
# 63                      1006       1006      1006
# 64                       478        478       478
# 65                     15590      15590     15590
# 66                     16095      16095     16095
# 70                        83         83        83
# 75                     21362      21362     21362
# 82                      5588       5588      5588
# 85                      3337       3337      3337
# 86                      1222       1222      1222
# 87                      3337       3337      3337
# 90                     16095      16095     16095
# 92                     15590      15590     15590
# 98                      3704       3704      3704
# 99                      3704       3704      3704
# 102                    15252      15252     15252
# ...                      ...        ...       ...
# 1341539                 8860       8860      8860
# 1341540                22209      22209     22209
# 1341542                22209      22209     22209
# 1341546                16272      16272     16272
# 1341575                 8860       8860      8860
# 1341579                22209      22209     22209
# 1341581                22209      22209     22209
# 1341583                 3987       3987      3987
# 1341584                 3987       3987      3987
# 1341585                 3247       3248      3248
# 1341586                  262        262       262
# 1341587                22209      22209     22209
# 1341588                16272      16272     16272
# 1341589                22209      22209     22209
# 1341590                 5975       5975      5975
# 1341592                22209      22209     22209
# 1341597                 4956       4956      4956
# 1341600                22209      22209     22209
# 1341601                22209      22209     22209
# 1341602                16272      16272     16272
# 1341603                 1863       1863      1863
# 1341604                 1863       1863      1863
# 1341618                 4956       4956      4956
# 1341626                 1925       1925      1925
# 1341629                 8860       8860      8860
# 1341631                19765      19765     19765
# 1341634                  411        411       411
# 1341637                  426        426       426
# 1341641                 8860       8860      8860
# 1341642                22209      22209     22209
#
# [792193 rows x 23 columns]

# %%
df_parroquias = df_anos
df_parroquias["cantidad"] = df_parroquias.groupby(["fecha_ano","DESCRIPCION_PARROQUIA"])["NUMERO_RUC"].transform(lambda x : x.count())
df_x_parroquia = df_parroquias[["DESCRIPCION_PARROQUIA","fecha_ano","FECHA_INICIO_ACTIVIDADES","cantidad"]]
df_x_parroquia.drop_duplicates(subset=["DESCRIPCION_PARROQUIA","fecha_ano","FECHA_INICIO_ACTIVIDADES"]).to_csv("por_parroquiasGuayaquil.csv", header=True, encoding="utf-8", index=False)
df_parroquias

# %% [markdown]
# ### Discretizando los datos - Nuevos contribuyentes
# Creamos una columna `PRESIDENTE` que determina el presidente durante el periodo de tiempo en que han registrado nuevos contribuyentes

# %%
mahuad_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(1998,8,10)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2000,1,22))].assign(PRESIDENTE='Jamil Mahuad')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
gn_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2000,1,22)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2003,1,5))].assign(PRESIDENTE='Gustavo Noboa')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
guti_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2003,1,5)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2005,4,20))].assign(PRESIDENTE='Lucio Gutiérrez')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
pala_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2005,4,20)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2007,1,15))].assign(PRESIDENTE='Alfredo Palacio')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc1_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2007,1,15)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2009,8,10))].assign(PRESIDENTE='Rafael Correa P1')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc2_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2009,8,10)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2013,5,24))].assign(PRESIDENTE='Rafael Correa P2')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc3_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2013,5,24)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2017,5,24))].assign(PRESIDENTE='Rafael Correa P3')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_per_ini = df[df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2017,5,24)].assign(PRESIDENTE='Lenín Moreno')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_per_ini.head()
# Out:
#           NUMERO_RUC                      RAZON_SOCIAL      NOMBRE_COMERCIAL  \
# ID
# 458318  919268458001  RODRIGUEZ ZAMBRANO RUDDY BEATRIZ                   NaN
# 458319  919375790001       BORJA CASTRO CARLOS ALBERTO                   NaN
# 458563  919433268001     ADRIAN BAJAÑA JAVIER HUMBERTO                   NaN
# 458564  919442624001         OLGUIN CORTEZ RAUL JAVIER  MIS TIERNOS DELFINES
# 470381  101868404001     BERNAL ANDRADE SALVADOR ELIAS                   NaN
#
#        ESTADO_CONTRIBUYENTE CLASE_CONTRIBUYENTE FECHA_INICIO_ACTIVIDADES  \
# ID
# 458318           SUSPENDIDO               OTROS               2017-12-06
# 458319           SUSPENDIDO               OTROS               2017-12-06
# 458563           SUSPENDIDO               OTROS               2017-12-06
# 458564           SUSPENDIDO               OTROS               2017-12-06
# 470381               ACTIVO                RISE               2018-01-23
#
#        FECHA_ACTUALIZACION FECHA_SUSPENSION_DEFINITIVA  \
# ID
# 458318                 NaN                  21/11/2017
# 458319                 NaN                  31/07/2018
# 458563                 NaN                  27/08/2018
# 458564          12/06/2017                  26/08/2018
# 470381          10/09/2018                         NaN
#
#        FECHA_REINICIO_ACTIVIDADES OBLIGADO  ...                 INTERSECCION  \
# ID                                          ...
# 458318                        NaN        N  ...                          NaN
# 458319                        NaN        N  ...                          NaN
# 458563                        NaN        N  ...                          NaN
# 458564                        NaN        N  ...                          NaN
# 470381                 10/09/2018        N  ...  MARACAIBO ENTRE  A GONZALEZ
#
#         ESTADO_ESTABLECIMIENTO DESCRIPCION_PROVINCIA DESCRIPCION_CANTON  \
# ID
# 458318                     CER                GUAYAS          GUAYAQUIL
# 458319                     CER                GUAYAS          GUAYAQUIL
# 458563                     CER                GUAYAS          GUAYAQUIL
# 458564                     CER                GUAYAS          GUAYAQUIL
# 470381                     ABI                GUAYAS          GUAYAQUIL
#
#        DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 458318                TARQUI     S960907
# 458319                TARQUI     C181104
# 458563                TARQUI     S952201
# 458564                TARQUI     I561001
# 470381        FEBRES CORDERO     G477111
#
#                                       ACTIVIDAD_ECONOMICA fecha_ano fecha_mes  \
# ID
# 458318  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2017       Dec
# 458319  ACTIVIDADES DE IMPRESIÓN DE PÓSTERS, GIGANTOGR...      2017       Dec
# 458563  REPARACIÓN Y MANTENIMIENTO DE APARATOS DE USO ...      2017       Dec
# 458564  RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...      2017       Dec
# 470381  VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...      2018       Jan
#
#           PRESIDENTE
# ID
# 458318  Lenín Moreno
# 458319  Lenín Moreno
# 458563  Lenín Moreno
# 458564  Lenín Moreno
# 470381  Lenín Moreno
#
# [5 rows x 25 columns]

# %%
cdf = pd.concat([mahuad_per_ini, gn_per_ini, guti_per_ini, pala_per_ini, rc1_per_ini, rc2_per_ini, rc3_per_ini, lenin_per_ini])

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='PRESIDENTE', data=cdf,color=COLOR)
ax.set(ylabel='PROMEDIO DE NUEVOS CONTRIBUYENTES POR DÍA',xlabel="PERIODOS PRESIDENCIALES", title='Promedio por día de nuevos contribuyentes deacuerdo al periodo presidencial',ylim=(0, 150))
total = float(len(cdf))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
uso_nuevos = dias_x_periodo.copy()
for p in ax.patches:
    dias = uso_nuevos.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %%
plt.figure(figsize=(16, 6))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498,780,1461,1322,969,635,826,1089,498,780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
uso_nuevos = dias_x_periodo.copy()
ax = sns.countplot(x='PRESIDENTE', data=cdf, hue="ESTADO_CONTRIBUYENTE",palette=sns.color_palette("Set1", n_colors=3, desat=.5))
ax.set(ylabel='PROMEDIO DE NUEVOS CONTRIBUYENTES POR DÍA',xlabel="PERIODOS PRESIDENCIALES", title='Promedio por día de nuevos contribuyentes por periodos presidenciales categorizados por el estado actual del contribuyente',ylim=(0, 100))
total = float(len(cdf))
for p in ax.patches:
    dias = uso_nuevos.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %%
df2 = guayaquil.dropna(subset=['FECHA_SUSPENSION_DEFINITIVA'])

# %%
df2
# Out:
#             NUMERO_RUC                                RAZON_SOCIAL  \
# ID
# 1         100092519001             BAYANCELA GONZALEZ HUGO ENRIQUE
# 2         100121268001                LUCERO VELEZ MANUEL SALVADOR
# 9         100160480001                  PEÑAFIEL DIAZ LUIS RODRIGO
# 11        100194281001               ARIZAGA MOREIRA EDGAR REMIGIO
# 12        100169242001                       OCHOA LEON EMMA LUCIA
# 13        100171081001                        CARRION LUIS ANTONIO
# 14        100171081001                        CARRION LUIS ANTONIO
# 15        100205392001               ORELLANA CORREA LUCAS AUGUSTO
# 16        100205392001               ORELLANA CORREA LUCAS AUGUSTO
# 17        100266030001      NUÑEZ DEL ARCO ANDRADE JORGE IVAN RENE
# 18        100241785001                           PUCHOL MARIA CRUZ
# 19        100241785001                           PUCHOL MARIA CRUZ
# 22        100330778001             AGUILERA BARZALLO CARLOS MANUEL
# 23        100349737001              LLIVISACA MEJIA MANUEL ROSENDO
# 24        100349737001              LLIVISACA MEJIA MANUEL ROSENDO
# 25        100358977001               NIETO CAMPOVERDE JOSE BENIGNO
# 26        100325596001               NACIPUCHA NAULA JULIO ENRIQUE
# 27        100403864001       SARMIENTO VILLAVICENCIO LUIS VIRGILIO
# 29        100419274001                 AREVALO GOMEZ MOIES ENRIQUE
# 30        100011972001                  MALO GONZALEZ JUAN RODRIGO
# 33        100134337001                MURILLO GOMEZ MANUEL IGNACIO
# 34        100069160001                PILCO NARVAEZ FAUSTO BOLIVAR
# 35        100069160001                PILCO NARVAEZ FAUSTO BOLIVAR
# 37        100079706001                 NUÑEZ VELEZ TEODORO ENRIQUE
# 46        100155480001                  SEMINARIO RIOS LUIS ULICES
# 48        100198605001               SINCHI MENDEZ MARIA CELESTINA
# 49        100240522001                   TAPIA TAPIA ESTHER LEONOR
# 55        100243583001              CULCAY ZAMBRANO MANUEL ERNESTO
# 56        100299734001              AREVALO HERNANDEZ ROSA AMERICA
# 57        100343144001                 LOYOLA VIVAR EFRAIN NICANOR
# ...                ...                                         ...
# 1340854   905901278001                 CARBO VEAS FLORINDA CECILIA
# 1340855   908744121001                ARGUELLO SANTOS SILVIA MARIA
# 1340871   803214600001            PEÑARRIETA MERA DIOGENES ALBERTO
# 1340872   803492776001               ESTUPIÑAN ROJA SILVIA DANIELA
# 1340873   924137706001              CASTILLO LOOR SANTIAGO GABRIEL
# 1340874   924146079001                 PLUAS LOZANO OMAR ALEXANDER
# 1340875   924388796001               ZUÑIGA VILLAO ELIZABETH PAOLA
# 1340876   924403025001               SANCHEZ PACHECO NARCISA DAYSI
# 1340896   801808510001                    GAMEZ SOLIZ WILMER AMADO
# 1340976  1309490033001                        ALVAREZ NARCILA INES
# 1341043  1311901696001               MECIAS CEDEÑO ROCIO ESTEFANIA
# 1341056   931109847001                 AGUILERA JIMENEZ GINA ALIDA
# 1341064   924624430001                 DIAZ MORANTE JENNIFER MARIA
# 1341066   926062407001                 PEÑAFIEL OCHOA JANIO JAVIER
# 1341106   927556860001               SANTANA GONZALEZ DARWIN ANGEL
# 1341250   944319490001             MACIAS MORALES DAYANA ANTONELLA
# 1341315  1207671940001                      PLUAS LUNA ERIKA PAOLA
# 1341324  1303944431001              CASANOVA CEDEÑO ROGERT ALBERTO
# 1341384   930078829001                    VELIZ SARANGO JUAN PABLO
# 1341390   930881925001           GALARZA SOLORZANO ESTHER CRISTINA
# 1341403   907310619001                     BRIONES CEPEDA JOB ESAU
# 1341426   917596256001              LIMONES BONOSO JESSICA NATACHA
# 1341518  1207073329001              PALACIOS TORRES NARCISA THALYA
# 1341618   501931513001                    COFRE LEMA BLANCA PIEDAD
# 1341629   915615306001  AQUINO DEL ROSARIO PATRICIA DE LOS ANGELES
# 1341631   915800445001                 QUINTO RUIZ CARLOTA LETICIA
# 1341634   916054422001             VARELA OLIVARES FRANKLIN GAVINO
# 1341637   941256414001               ZAMBRANO VERGARA ERIKA KARINA
# 1341641   941504813001                MUÑOZ CEDEÑO GABRIEL ENRIQUE
# 1341642   941560864001           CASTILLO MOSQUERA NAHOMY BRIGITTE
#
#                   NOMBRE_COMERCIAL ESTADO_CONTRIBUYENTE CLASE_CONTRIBUYENTE  \
# ID
# 1                              NaN               PASIVO               OTROS
# 2                              NaN           SUSPENDIDO               OTROS
# 9                              NaN           SUSPENDIDO               OTROS
# 11                             NaN           SUSPENDIDO               OTROS
# 12                             NaN           SUSPENDIDO               OTROS
# 13             ALMACEN ROLANDO N 1               PASIVO               OTROS
# 14             ALMACEN ROLANDO N 1               PASIVO               OTROS
# 15                             NaN           SUSPENDIDO               OTROS
# 16                             NaN           SUSPENDIDO               OTROS
# 17                             NaN           SUSPENDIDO               OTROS
# 18                             NaN           SUSPENDIDO               OTROS
# 19                             NaN           SUSPENDIDO               OTROS
# 22                             NaN               PASIVO               OTROS
# 23                             NaN           SUSPENDIDO               OTROS
# 24                             NaN           SUSPENDIDO               OTROS
# 25                             NaN           SUSPENDIDO               OTROS
# 26                             NaN           SUSPENDIDO               OTROS
# 27                             NaN               PASIVO               OTROS
# 29       PICANTERIA TRES ARBOLITOS               PASIVO               OTROS
# 30                             NaN           SUSPENDIDO               OTROS
# 33                             NaN               PASIVO               OTROS
# 34                             NaN           SUSPENDIDO               OTROS
# 35                             NaN           SUSPENDIDO               OTROS
# 37                             NaN           SUSPENDIDO               OTROS
# 46                             NaN           SUSPENDIDO               OTROS
# 48                             NaN           SUSPENDIDO               OTROS
# 49                             NaN           SUSPENDIDO               OTROS
# 55                             NaN           SUSPENDIDO               OTROS
# 56                 HELADERIA TOPSY           SUSPENDIDO               OTROS
# 57                             NaN           SUSPENDIDO               OTROS
# ...                            ...                  ...                 ...
# 1340854                        NaN           SUSPENDIDO               OTROS
# 1340855                        NaN           SUSPENDIDO               OTROS
# 1340871                        NaN           SUSPENDIDO               OTROS
# 1340872                        NaN           SUSPENDIDO               OTROS
# 1340873                        NaN           SUSPENDIDO               OTROS
# 1340874                        NaN           SUSPENDIDO               OTROS
# 1340875                        NaN           SUSPENDIDO               OTROS
# 1340876                        NaN           SUSPENDIDO               OTROS
# 1340896                        NaN           SUSPENDIDO               OTROS
# 1340976                        NaN           SUSPENDIDO               OTROS
# 1341043                        NaN           SUSPENDIDO               OTROS
# 1341056                        NaN           SUSPENDIDO               OTROS
# 1341064                        NaN           SUSPENDIDO               OTROS
# 1341066                    LA KALA           SUSPENDIDO               OTROS
# 1341106                        NaN           SUSPENDIDO               OTROS
# 1341250                        NaN           SUSPENDIDO               OTROS
# 1341315                        NaN           SUSPENDIDO               OTROS
# 1341324                        NaN               ACTIVO               OTROS
# 1341384                        NaN           SUSPENDIDO               OTROS
# 1341390                        NaN           SUSPENDIDO               OTROS
# 1341403                        NaN           SUSPENDIDO               OTROS
# 1341426                        NaN           SUSPENDIDO               OTROS
# 1341518                        NaN           SUSPENDIDO               OTROS
# 1341618                        NaN           SUSPENDIDO               OTROS
# 1341629                        NaN           SUSPENDIDO               OTROS
# 1341631                        NaN           SUSPENDIDO               OTROS
# 1341634                        NaN           SUSPENDIDO               OTROS
# 1341637                        NaN           SUSPENDIDO               OTROS
# 1341641                        NaN           SUSPENDIDO               OTROS
# 1341642                        NaN           SUSPENDIDO               OTROS
#
#         FECHA_INICIO_ACTIVIDADES FECHA_ACTUALIZACION  \
# ID
# 1                     20/11/1973          29/05/2008
# 2                     30/04/1998          09/07/2009
# 9                     17/08/1995          04/02/2015
# 11                    01/06/1999          13/06/2001
# 12                    19/04/1997          07/12/2001
# 13                    07/08/1972          13/08/1999
# 14                    07/08/1972          13/08/1999
# 15                    02/04/1972          04/10/2011
# 16                    02/04/1972          04/10/2011
# 17                    01/01/1974          20/02/2013
# 18                    07/12/1999          04/03/2015
# 19                    07/12/1999          04/03/2015
# 22                    30/04/1973          20/06/1994
# 23                    11/01/1979          18/05/2006
# 24                    11/01/1979          18/05/2006
# 25                    18/06/1970          18/01/2000
# 26                    16/02/1993                 NaN
# 27                    25/04/1996          25/04/2005
# 29                    13/08/1990          05/11/2003
# 30                    19/02/2002          06/06/2002
# 33                    01/12/1974          05/01/2005
# 34                    31/01/2002          03/06/2015
# 35                    31/01/2002          03/06/2015
# 37                    17/01/1994          02/02/2004
# 46                    17/08/1999          10/05/2000
# 48                    30/05/1985          25/10/2000
# 49                    26/07/1994          23/05/2014
# 55                    22/02/1979                 NaN
# 56                    01/10/1987          28/02/2007
# 57                    01/08/1997          08/03/2002
# ...                          ...                 ...
# 1340854               04/09/2018                 NaN
# 1340855               04/09/2018                 NaN
# 1340871               02/07/2018                 NaN
# 1340872               04/07/2018                 NaN
# 1340873               23/07/2018                 NaN
# 1340874               29/06/2017                 NaN
# 1340875               17/07/2018                 NaN
# 1340876               20/02/2017                 NaN
# 1340896               29/01/2019                 NaN
# 1340976               26/06/2018          26/06/2018
# 1341043               08/11/2018          17/01/2019
# 1341056               16/04/2018                 NaN
# 1341064               25/01/2019                 NaN
# 1341066               21/06/2006          25/01/2019
# 1341106               09/07/2018                 NaN
# 1341250               05/12/2018                 NaN
# 1341315               03/01/2019                 NaN
# 1341324               22/10/1991          23/01/2019
# 1341384               31/07/2018                 NaN
# 1341390               05/04/2016                 NaN
# 1341403               29/01/2019          29/01/2019
# 1341426               02/01/2019                 NaN
# 1341518               06/10/2015          07/02/2019
# 1341618               26/07/2018                 NaN
# 1341629               12/03/2018                 NaN
# 1341631               05/03/2012          08/04/2013
# 1341634               04/09/2018                 NaN
# 1341637               06/07/2018                 NaN
# 1341641               25/07/2018                 NaN
# 1341642               18/07/2018          18/07/2018
#
#         FECHA_SUSPENSION_DEFINITIVA FECHA_REINICIO_ACTIVIDADES OBLIGADO  ...  \
# ID                                                                       ...
# 1                        29/09/2009                        NaN        N  ...
# 2                        31/08/2011                        NaN        N  ...
# 9                        09/09/2018                 04/02/2015        N  ...
# 11                       13/09/2006                        NaN        N  ...
# 12                       13/07/2010                        NaN        N  ...
# 13                       30/12/1978                 01/01/1981        N  ...
# 14                       30/12/1978                 01/01/1981        N  ...
# 15                       18/11/2011                 04/10/2011        S  ...
# 16                       18/11/2011                 04/10/2011        S  ...
# 17                       11/07/2017                 20/02/2013        N  ...
# 18                       01/09/2018                 04/03/2015        N  ...
# 19                       01/09/2018                 04/03/2015        N  ...
# 22                       02/08/1998                        NaN        N  ...
# 23                       13/07/2010                        NaN        N  ...
# 24                       13/07/2010                        NaN        N  ...
# 25                       13/07/2010                        NaN        N  ...
# 26                       13/07/2010                        NaN        N  ...
# 27                       03/07/2009                        NaN        N  ...
# 29                       29/09/2009                        NaN        N  ...
# 30                       19/02/2002                        NaN        N  ...
# 33                       30/09/2008                        NaN        N  ...
# 34                       06/03/2017                 17/10/2014        N  ...
# 35                       06/03/2017                 17/10/2014        N  ...
# 37                       13/07/2010                 02/02/2004        N  ...
# 46                       13/09/2006                        NaN        N  ...
# 48                       03/05/1985                        NaN        N  ...
# 49                       31/07/2018                 23/05/2014        N  ...
# 55                       16/04/2007                        NaN        N  ...
# 56                       13/07/2010                        NaN        N  ...
# 57                       13/09/2006                        NaN        N  ...
# ...                             ...                        ...      ...  ...
# 1340854                  04/09/2018                        NaN        N  ...
# 1340855                  04/09/2018                        NaN        N  ...
# 1340871                  07/02/2019                        NaN        N  ...
# 1340872                  07/02/2019                        NaN        N  ...
# 1340873                  07/02/2019                        NaN        N  ...
# 1340874                  07/02/2019                        NaN        N  ...
# 1340875                  07/02/2019                        NaN        N  ...
# 1340876                  07/02/2019                        NaN        N  ...
# 1340896                  29/01/2019                        NaN        N  ...
# 1340976                  09/01/2019                        NaN        N  ...
# 1341043                  21/01/2019                 17/01/2019        N  ...
# 1341056                  08/11/2018                        NaN        N  ...
# 1341064                  30/01/2019                        NaN        N  ...
# 1341066                  08/02/2019                 24/01/2019        N  ...
# 1341106                  07/02/2019                        NaN        N  ...
# 1341250                  04/02/2019                        NaN        N  ...
# 1341315                  16/01/2019                        NaN        N  ...
# 1341324                  18/01/2019                 23/01/2019        N  ...
# 1341384                  07/02/2019                        NaN        N  ...
# 1341390                  07/02/2019                        NaN        N  ...
# 1341403                  31/01/2019                        NaN        N  ...
# 1341426                  21/01/2019                        NaN        N  ...
# 1341518                  07/02/2019                        NaN        N  ...
# 1341618                  07/02/2019                        NaN        N  ...
# 1341629                  07/02/2019                        NaN        N  ...
# 1341631                  07/02/2019                 08/04/2013        N  ...
# 1341634                  04/09/2018                        NaN        N  ...
# 1341637                  07/02/2019                        NaN        N  ...
# 1341641                  07/02/2019                        NaN        N  ...
# 1341642                  07/02/2019                        NaN        N  ...
#
#                NOMBRE_FANTASIA_COMERCIAL                          CALLE  \
# ID
# 1                                    NaN                        BOLIVIA
# 2                                    NaN                        29 AVA.
# 9                                    NaN                            NaN
# 11                                   NaN                            NaN
# 12                                   NaN                      VENEZUELA
# 13                     ALMACEN ROLANDO 2            LORENZO DE GARAYCOA
# 14                   ALMACEN ROLANDO N 1            LORENZO DE GARAICOA
# 15         ORELLANA CORREA LUCAS AUGUSTO               JOSE DE ANTEPARA
# 16                                   NaN                            NaN
# 17                               ALEBUHO                            NaN
# 18                                   NaN                          CHILE
# 19                                   NaN                          CHILE
# 22                                   NaN          VICTOR EMILIO ESTRADA
# 23                             TELE ROSS                 LEONIDAS PLAZA
# 24                                   NaN                 LEONIDAS PLAZA
# 25                                   NaN                  GARCIA GOYENA
# 26                                   NaN                       AYACUCHO
# 27                                   NaN                            NaN
# 29             PICANTERIA TRES ARBOLITOS                         24 AVA
# 30                                   NaN                    AV. PRIMERA
# 33                           FOTO GUAYAS                              D
# 34                                   NaN                          VELEZ
# 35                     FARMACIA SERVIMAS                            NaN
# 37                                   NaN                            NaN
# 46                                   NaN        FRANCISCO DE P. LAVAYEN
# 48                                   NaN                            NaN
# 49                                   NaN                       CHAMBERS
# 55                                   NaN  COOP.FUND.DE GQUIL.MZ. 3 S-17
# 56                       HELADERIA TOPSY                            NaN
# 57                                   NaN                            NaN
# ...                                  ...                            ...
# 1340854                              NaN                            NaN
# 1340855                              NaN                            NaN
# 1340871                              NaN                            NaN
# 1340872                              NaN                3 PASAJE 38B NO
# 1340873                              NaN                        PORTETE
# 1340874                              NaN                            NaN
# 1340875                              NaN                   10 DE AGOSTO
# 1340876           TIENDA CUATRO HERMANOS                            NaN
# 1340896                              NaN                            NaN
# 1340976  PRODUCTOS Y DESAYUNOS MANABITAS                           38VA
# 1341043                              NaN                      VENEZUELA
# 1341056                              NaN                            NaN
# 1341064                              NaN                            NaN
# 1341066                          LA KALA             CDLA MARTHA ROLDOS
# 1341106                              NaN                            NaN
# 1341250  DAYANA ANTONELLA MACIAS MORALES                    MANZANA 2 D
# 1341315                              NaN                            NaN
# 1341324                              NaN  CDLA LAS ACACIAS MZ A 1 VILLA
# 1341384                              NaN                            NaN
# 1341390                              NaN                            NaN
# 1341403                              NaN                    CALICUCHIMA
# 1341426                              NaN                            NaN
# 1341518                              NaN                  GARCIA AVILES
# 1341618                              NaN                            NaN
# 1341629                              NaN                            NaN
# 1341631                              NaN                            NaN
# 1341634                              NaN                            NaN
# 1341637                              NaN                        MALECON
# 1341641                              NaN                            NaN
# 1341642                              NaN                  5TO. CALLEJON
#
#            NUMERO                   INTERSECCION ESTADO_ESTABLECIMIENTO  \
# ID
# 1            1300                            NaN                    CER
# 2            4805              CALLE O - CALLE P                    CER
# 9        SOLAR 21                            NaN                    CER
# 11          SL. 6                            NaN                    CER
# 12           3716                         12 AVA                    CER
# 13           1817              PEDRO PABLO GOMEZ                    CER
# 14           1509                          SUCRE                    CER
# 15           1912                            NaN                    CER
# 16        SOLAR 5                            NaN                    CER
# 17       SOLAR 70                            NaN                    CER
# 18            S/N              AYACUCHO - MANABI                    CER
# 19            S/N              AYACUCHO - MANABI                    CER
# 22           1121              LAURELES Y JIGUAS                    CER
# 23           3027                  DOMINGO SAVIO                    CER
# 24           3027                  DOMINGO SAVIO                    CER
# 25            S/N  ABEL CASTILLO - G. VALENZUELA                    CER
# 26            S/N                    HUAYNACAPAC                    CER
# 27       VILLA 36                            NaN                    CER
# 29            NaN                      ARGENTINA                    CER
# 30            520                     CALLE 4TA.                    CER
# 33           1200                        25 AVA.                    CER
# 34            905                     6 DE MARZO                    CER
# 35        SOLAR 3                            NaN                    CER
# 37        SOLAR 2                            NaN                    CER
# 46            114                 CALIXTO ROMERO                    CER
# 48       SOLAR 16                            NaN                    CER
# 49           5715              46 AVA. - 47 AVA.                    CER
# 55            S/N                            NaN                    CER
# 56       SOLAR 18                            NaN                    CER
# 57         SL. 13                            NaN                    CER
# ...           ...                            ...                    ...
# 1340854       NaN                            NaN                    CER
# 1340855       NaN                            NaN                    CER
# 1340871  SOLAR 23                            NaN                    CER
# 1340872  VILLA 40                            NaN                    CER
# 1340873      1212            GUARANDA-P.MONTUFAR                    CER
# 1340874  SOLAR 16                            NaN                    CER
# 1340875      3222         G. MARTINEZ-N. SEGOVIA                    CER
# 1340876  SOLAR 11                            NaN                    CER
# 1340896  SOLAR 11                            NaN                    CER
# 1340976      1405               V.GALINDO-EL ORO                    CER
# 1341043      6203              35VA.-36VA.CALLES                    CER
# 1341056    SOL#16                            NaN                    CER
# 1341064  SOLAR 36                            NaN                    CER
# 1341066   VILLA 7                      CALLE 18C                    CER
# 1341106    SOL# 7                            NaN                    CER
# 1341250   VILLA 7                AV. LANEADO WIN                    CER
# 1341315  SOLAR 14                            NaN                    CER
# 1341324       S/N                            NaN                    CER
# 1341384    SL. 03                            NaN                    CER
# 1341390  SOLAR 21                            NaN                    CER
# 1341403      3511                    11VA - 12VA                    CER
# 1341426     SL. 8                            NaN                    CER
# 1341518       505                          LUQUE                    CER
# 1341618     SOL 4                            NaN                    CER
# 1341629  SOLAR 12                            NaN                    CER
# 1341631  SOLAR 10                            NaN                    CER
# 1341634       NaN                            NaN                    CER
# 1341637       S/N                            NaN                    CER
# 1341641   SOLAR 5                            NaN                    CER
# 1341642       478                            NaN                    CER
#
#         DESCRIPCION_PROVINCIA DESCRIPCION_CANTON DESCRIPCION_PARROQUIA  \
# ID
# 1                      GUAYAS          GUAYAQUIL         GARCIA MORENO
# 2                      GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 9                      GUAYAS          GUAYAQUIL                TARQUI
# 11                     GUAYAS          GUAYAQUIL                TARQUI
# 12                     GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 13                     GUAYAS          GUAYAQUIL            ROCAFUERTE
# 14                     GUAYAS          GUAYAQUIL            ROCAFUERTE
# 15                     GUAYAS          GUAYAQUIL                 SUCRE
# 16                     GUAYAS          GUAYAQUIL                TARQUI
# 17                     GUAYAS          GUAYAQUIL                TARQUI
# 18                     GUAYAS          GUAYAQUIL    OLMEDO (SAN ALEJO)
# 19                     GUAYAS          GUAYAQUIL    OLMEDO (SAN ALEJO)
# 22                     GUAYAS          GUAYAQUIL                TARQUI
# 23                     GUAYAS          GUAYAQUIL             LETAMENDI
# 24                     GUAYAS          GUAYAQUIL             LETAMENDI
# 25                     GUAYAS          GUAYAQUIL             LETAMENDI
# 26                     GUAYAS          GUAYAQUIL    OLMEDO (SAN ALEJO)
# 27                     GUAYAS          GUAYAQUIL                XIMENA
# 29                     GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 30                     GUAYAS          GUAYAQUIL                TARQUI
# 33                     GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 34                     GUAYAS          GUAYAQUIL                XIMENA
# 35                     GUAYAS          GUAYAQUIL                TARQUI
# 37                     GUAYAS          GUAYAQUIL                TARQUI
# 46                     GUAYAS          GUAYAQUIL    OLMEDO (SAN ALEJO)
# 48                     GUAYAS          GUAYAQUIL                TARQUI
# 49                     GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 55                     GUAYAS          GUAYAQUIL                XIMENA
# 56                     GUAYAS          GUAYAQUIL                XIMENA
# 57                     GUAYAS          GUAYAQUIL                TARQUI
# ...                       ...                ...                   ...
# 1340854                GUAYAS          GUAYAQUIL                TARQUI
# 1340855                GUAYAS          GUAYAQUIL                TARQUI
# 1340871                GUAYAS          GUAYAQUIL                TARQUI
# 1340872                GUAYAS          GUAYAQUIL                TARQUI
# 1340873                GUAYAS          GUAYAQUIL         GARCIA MORENO
# 1340874                GUAYAS          GUAYAQUIL                TARQUI
# 1340875                GUAYAS          GUAYAQUIL              URDANETA
# 1340876                GUAYAS          GUAYAQUIL                TARQUI
# 1340896                GUAYAS          GUAYAQUIL                XIMENA
# 1340976                GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 1341043                GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 1341056                GUAYAS          GUAYAQUIL                TARQUI
# 1341064                GUAYAS          GUAYAQUIL                TARQUI
# 1341066                GUAYAS          GUAYAQUIL                TARQUI
# 1341106                GUAYAS          GUAYAQUIL                TARQUI
# 1341250                GUAYAS          GUAYAQUIL                TARQUI
# 1341315                GUAYAS          GUAYAQUIL                TARQUI
# 1341324                GUAYAS          GUAYAQUIL                XIMENA
# 1341384                GUAYAS          GUAYAQUIL                XIMENA
# 1341390                GUAYAS          GUAYAQUIL                TARQUI
# 1341403                GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 1341426                GUAYAS          GUAYAQUIL                TARQUI
# 1341518                GUAYAS          GUAYAQUIL            ROCAFUERTE
# 1341618                GUAYAS          GUAYAQUIL        FEBRES CORDERO
# 1341629                GUAYAS          GUAYAQUIL                XIMENA
# 1341631                GUAYAS          GUAYAQUIL                TARQUI
# 1341634                GUAYAS          GUAYAQUIL              URDANETA
# 1341637                GUAYAS          GUAYAQUIL               POSORJA
# 1341641                GUAYAS          GUAYAQUIL                XIMENA
# 1341642                GUAYAS          GUAYAQUIL                TARQUI
#
#         CODIGO_CIIU                                ACTIVIDAD_ECONOMICA
# ID
# 1           Q862001  CONSULTA Y TRATAMIENTO POR MÉDICOS GENERALES Y...
# 2           H492101  TRANSPORTE TERRESTRE DE PASAJEROS POR SISTEMAS...
# 9           L682002  INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 11          G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 12          G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 13          G477205  VENTA AL POR MENOR DE PERFUMES, ARTÍCULOS COSM...
# 14          G477205  VENTA AL POR MENOR DE PERFUMES, ARTÍCULOS COSM...
# 15          A016309  OTRAS ACTIVIDADES DE POSCOSECHA: DESMOTADO DE ...
# 16          A016309  OTRAS ACTIVIDADES DE POSCOSECHA: DESMOTADO DE ...
# 17          M749010  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 18          G464124  VENTA AL POR MAYOR DE ARTÍCULOS DE BAZAR EN GE...
# 19          G464124  VENTA AL POR MAYOR DE ARTÍCULOS DE BAZAR EN GE...
# 22          G463022  VENTA AL POR MAYOR DE HUEVOS Y PRODUCTOS A BAS...
# 23          S952201  REPARACIÓN Y MANTENIMIENTO DE APARATOS DE USO ...
# 24          S952201  REPARACIÓN Y MANTENIMIENTO DE APARATOS DE USO ...
# 25          G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 26          G472101  VENTA AL POR MENOR DE FRUTAS, LEGUMBRES Y HORT...
# 27          H492101  TRANSPORTE TERRESTRE DE PASAJEROS POR SISTEMAS...
# 29          I563002  ACTIVIDADES DE PREPARACIÓN Y SERVICIO DE BEBID...
# 30          W200000  ACTIVIDADES LABORALES REALIZADAS BAJO RELACION...
# 33          M742001  REALIZACIÓN DE RETRATOS FOTOGRÁFICOS PARA PASA...
# 34          M691009  OTRAS ACTIVIDADES DE ASESORAMIENTO Y REPRESENT...
# 35          M691009  OTRAS ACTIVIDADES DE ASESORAMIENTO Y REPRESENT...
# 37          M692009  OTRAS ACTIVIDADES DE CONTABILIDAD, TENEDURÍA D...
# 46          G477121  VENTA AL POR MENOR DE CALZADO, MATERIAL DE ZAP...
# 48          G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 49          L682002  INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 55          G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 56          I561002  RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...
# 57          H492202                                SERVICIOS DE TAXIS.
# ...             ...                                                ...
# 1340854     V030000                     SIN ACTIVIDAD ECONOMICA - CIIU
# 1340855     V030000                     SIN ACTIVIDAD ECONOMICA - CIIU
# 1340871     S960907  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1340872     I561001  RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...
# 1340873     G452001  MANTENIMIENTO Y REPARACIÓN DE VEHÍCULOS AUTOMO...
# 1340874     C310001  FABRICACIÓN DE MUEBLES DE MADERA Y SUS PARTES:...
# 1340875     G464995  VENTA AL POR MAYOR DE ARTÍCULOS DE PORCELANA, ...
# 1340876     G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 1340896     S960200  ACTIVIDADES DE LAVADO, CORTE, RECORTE, PEINADO...
# 1340976     I561003  PREPARACIÓN Y SUMINISTRO DE COMIDAS PARA SU CO...
# 1341043     T970000  ACTIVIDADES DE LOS HOGARES COMO EMPLEADORES DE...
# 1341056     A011200  CULTIVO DE ARROZ (INCLUIDO EL CULTIVO ORGÁNICO...
# 1341064     I561002  RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...
# 1341066     I562100  SERVICIO DE COMIDAS BASADO EN ACUERDOS CONTRAC...
# 1341106     S951201  REPARACIÓN Y MANTENIMIENTO DE TELÉFONOS INALÁM...
# 1341250     S960907  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1341315     P854911  ACTIVIDADES DE ENSEÑANZA QUE NO PUEDE ASIGNARS...
# 1341324     G462021              VENTA AL POR MAYOR DE ANIMALES VIVOS.
# 1341384     H531000  SERVICIOS DE RECOLECCIÓN DE CORRESPONDENCIA Y ...
# 1341390     G477111  VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...
# 1341403     F433041  PINTURA INTERIOR O EXTERIOR DE EDIFICIOS. INCL...
# 1341426     M749010  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 1341518     G464124  VENTA AL POR MAYOR DE ARTÍCULOS DE BAZAR EN GE...
# 1341618     G471101  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 1341629     G471900  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 1341631     I563002  ACTIVIDADES DE PREPARACIÓN Y SERVICIO DE BEBID...
# 1341634     V030000                     SIN ACTIVIDAD ECONOMICA - CIIU
# 1341637     G474113  VENTA AL POR MENOR DE EQUIPOS DE TELECOMUNICAC...
# 1341641     G472101  VENTA AL POR MENOR DE FRUTAS, LEGUMBRES Y HORT...
# 1341642     S960200  ACTIVIDADES DE LAVADO, CORTE, RECORTE, PEINADO...
#
# [565108 rows x 22 columns]

# %%
df2['FECHA_SUSPENSION_DEFINITIVA'] = pd.to_datetime(df2['FECHA_SUSPENSION_DEFINITIVA'])
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mahuad_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(1998,8,10)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2000,1,22))].assign(PRESIDENTE='Jamil Mahuad')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
gn_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2000,1,22)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2003,1,5))].assign(PRESIDENTE='Gustavo Noboa')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
guti_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2003,1,5)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2005,4,20))].assign(PRESIDENTE='Lucio Gutiérrez')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
pala_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2005,4,20)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2007,1,15))].assign(PRESIDENTE='Alfredo Palacio')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc1_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2007,1,15)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2009,8,10))].assign(PRESIDENTE='Rafael Correa P1')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc2_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2009,8,10)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2013,5,24))].assign(PRESIDENTE='Rafael Correa P2')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc3_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2013,5,24)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2017,5,24))].assign(PRESIDENTE='Rafael Correa P3')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_susp = df2[df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2017,5,24)].assign(PRESIDENTE='Lenín Moreno')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
cdf2 = pd.concat([mahuad_susp,gn_susp, guti_susp, pala_susp, rc1_susp, rc2_susp, rc3_susp, lenin_susp])

# %%
plt.figure(figsize=(16, 6))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
ax = sns.countplot(x='PRESIDENTE', data=cdf2,color=COLOR)
ax.set(ylabel='PROMEDIO CONTRIBUYENTES SUSPENDIDOS POR DÍA', xlabel="PERIODOS PRESIDENCIALES",title='Promedio por día de contribuyentes suspendidos deacuerdo al periodo presidencial',ylim=(0, 250))
total = float(len(cdf))
for p in ax.patches:
    dias = dias_x_periodo.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %% [markdown]
# ### Cantidad de establecimientos por tipo de actividad

# %%
df3 = guayaquil.dropna(subset=['ACTIVIDAD_ECONOMICA'])

# %%
len(df3['ACTIVIDAD_ECONOMICA'].unique())
# Out:
# 1626

# %%
top10 = df3.groupby('ACTIVIDAD_ECONOMICA').size().to_frame('cantidad').sort_values(['cantidad'], ascending=False).reset_index()[:11]
top10['ACTIVIDAD_ECONOMICA_MIN'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
top10['ACTIVIDAD_ECONOMICA'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:55], axis=1)

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN', data=top10,hue="ACTIVIDAD_ECONOMICA",palette=sns.color_palette("Set1", n_colors=10, desat=.5))
ax.set(ylabel='CANTIDAD DE ESTABLECIMIENTOS',xlabel="ACTIVIDAD ECONÓMICA", title='Cantidad de establecimientos por actividad ecónomica')
ax.set_xticklabels(labels=top10['ACTIVIDAD_ECONOMICA_MIN'],rotation=90)
top10["ACTIVIDAD_ECONOMICA"][:]
# Out:
# 0     RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...
# 1     VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 2     INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, M...
# 3     ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 4     OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 5     INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 6     VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 7     COMPRA - VENTA, ALQUILER Y EXPLOTACIÓN DE BIEN...
# 8     CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDEN...
# 9     VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...
# 10    SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASI...
# Name: ACTIVIDAD_ECONOMICA, dtype: object

# %% [markdown]
# ### Cantidad de contribuyentes por actividad

# %%
cont_act = df3[['ACTIVIDAD_ECONOMICA', 'NUMERO_RUC']].groupby(['ACTIVIDAD_ECONOMICA'])

# %%
top10_cont = cont_act['NUMERO_RUC'].nunique().to_frame('cantidad').sort_values('cantidad', ascending=False).reset_index()[:11]
top10_cont['ACTIVIDAD_ECONOMICA_MIN'] = top10_cont.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
top10_cont['ACTIVIDAD_ECONOMICA'] = top10_cont.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:50], axis=1)

# %%
top10_cont
# Out:
#                                   ACTIVIDAD_ECONOMICA  cantidad  \
# 0   VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...     38936
# 1   RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...     37108
# 2   INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, M...     30740
# 3   ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...     25510
# 4   OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...     23584
# 5   COMPRA - VENTA, ALQUILER Y EXPLOTACIÓN DE BIEN...     18859
# 6   INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...     18493
# 7   VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...     18171
# 8   CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDEN...     17035
# 9   SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASI...     15531
# 10  VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...     14691
#
#       ACTIVIDAD_ECONOMICA_MIN
# 0   VENTA AL POR MENOR DE GRA
# 1   RESTAURANTES, CEVICHERÍAS
# 2   INTERMEDIARIOS DEL COMERC
# 3   ACTIVIDADES DE LIMPIABOTA
# 4   OTRAS ACTIVIDADES PROFESI
# 5   COMPRA - VENTA, ALQUILER
# 6   INTERMEDIACIÓN EN LA COMP
# 7   VENTA AL POR MENOR DE GRA
# 8   CONSTRUCCIÓN DE TODO TIPO
# 9   SERVICIOS DE  ASESORAMIEN
# 10  VENTA AL POR MENOR DE PRE

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN', data=top10_cont,hue="ACTIVIDAD_ECONOMICA",palette=sns.color_palette("Set1", n_colors=10, desat=.5))
ax.set(ylabel='CANTIDAD DE CONTRIBUYENTES', title='Cantidad de contribuyentes por Actividad',xlabel="ACTIVIDAD ECÓNOMICA")
ax.set_xticklabels(labels=top10_cont['ACTIVIDAD_ECONOMICA'],rotation=90)
# Out:
# [Text(0, 0, 'VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCTOS E'),
#  Text(0, 0, 'RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETERÍAS'),
#  Text(0, 0, 'INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, MINER'),
#  Text(0, 0, 'ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEADORE'),
#  Text(0, 0, 'OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y TÉC'),
#  Text(0, 0, 'COMPRA - VENTA, ALQUILER Y EXPLOTACIÓN DE BIENES I'),
#  Text(0, 0, 'INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER DE B'),
#  Text(0, 0, 'VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCTOS E'),
#  Text(0, 0, 'CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDENCIAL'),
#  Text(0, 0, 'SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASISTEN')]

# %%
df3 = df3.dropna(subset=['FECHA_INICIO_ACTIVIDADES'])
df3['FECHA_INICIO_ACTIVIDADES'] = pd.to_datetime(df3['FECHA_INICIO_ACTIVIDADES'])
df3['fecha_ano'] = df3['FECHA_INICIO_ACTIVIDADES'].dt.year
def mapper(month):
    return month.strftime('%b') 
df3['fecha_mes'] = df3['FECHA_INICIO_ACTIVIDADES'].apply(mapper)

# %%
lista_colores = sns.color_palette("muted", n_colors=20, desat=1)
palette = dict(zip(top10['ACTIVIDAD_ECONOMICA'].head(1),"blue"))
dic = []
def por_actividad_mes(ano):
    plt.figure(figsize=(26, 10))
    df_x = df3[df3['fecha_ano']==ano ]
    top10 = df_x.groupby('ACTIVIDAD_ECONOMICA').size().to_frame('cantidad').sort_values(['cantidad'], ascending=False).reset_index()[:5]
    top10['ACTIVIDAD_ECONOMICA'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:55], axis=1)
    top10['ACTIVIDAD_ECONOMICA_MIN'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
    for actividad in top10['ACTIVIDAD_ECONOMICA']:
        if actividad not in dic:
            dic.append(actividad)
            palette.update({actividad:lista_colores.pop()})
    ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN',ci=None, data=top10,hue="ACTIVIDAD_ECONOMICA",palette=palette)
    ax.set(ylabel='CANTIDAD DE ESTABLECIMIENTOS',xlabel="ACTIVIDAD ECONÓMICA", title='Cantidad de establecimientos por actividad ecónomica '+ str(ano))
    ax.set_xticklabels(labels=top10['ACTIVIDAD_ECONOMICA_MIN'],rotation=90)
    plt.savefig("CONTRIBUYENTES_X_ANO_"+str(ano)+".png")
df3 = df3[ (1998 <=df3['fecha_ano']) & (df3['fecha_ano']<=2018)]
for ano in df3['fecha_ano'].unique().tolist():
    por_actividad_mes(ano)
#convert -delay 30 *.png establecimiento_actividad_ano.gif
len(lista_colores)
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 0

# %% [markdown]
# # Análisis univariado y multivariado

# %% [markdown]
# Se usarán las siguientes variables para el análisis:
# * **FECHA_INICIO_ACTIVIDADES:** Muestra el inicio de actividades del contribuyente, para el análisis se pueden establecer periodos (presidenciales, municipales, etc) y obtener una relación entre aquel y la cantidad de nuevos negocios.
# * **FECHA_SUSPENSION_DEFINITIVA:** Fechas en las que un negocio dejó de operar. El análisis de esta variable nos ayudará a determinar en qué periodo temporal desaparecieron negocios, con lo que podremos analizar las medidas económicas tomadas por las instituciones alrededor de aquel periodo
# * **ACTIVIDAD_ECONOMICA:** Define el tipo de actividad que el contribuyente ejerce. Con esta variable podemos generar grupos y poder profundizar el análisis
# * **NUMERO_ESTABLECIMIENTO:** Número secuencial. Permite  conocer  el  orden  cronológico  de  la  creación  de los establecimientos.

# %%
import csv  # library csv
import pandas as pd  # library pandas
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
FILE_NAME = 'Proyecto/QUITO.csv'
COLOR = "tan"

# %%
guayaquil = pd.read_csv(FILE_NAME, sep=',', encoding='utf-8', error_bad_lines=False, index_col=0)  # reading GUAYAQUIL file

# %%
guayaquil.columns
# Out:
# Index(['NUMERO_RUC', 'RAZON_SOCIAL', 'NOMBRE_COMERCIAL',
#        'ESTADO_CONTRIBUYENTE', 'CLASE_CONTRIBUYENTE',
#        'FECHA_INICIO_ACTIVIDADES', 'FECHA_ACTUALIZACION',
#        'FECHA_SUSPENSION_DEFINITIVA', 'FECHA_REINICIO_ACTIVIDADES', 'OBLIGADO',
#        'TIPO_CONTRIBUYENTE', 'NUMERO_ESTABLECIMIENTO',
#        'NOMBRE_FANTASIA_COMERCIAL', 'CALLE', 'NUMERO', 'INTERSECCION',
#        'ESTADO_ESTABLECIMIENTO', 'DESCRIPCION_PROVINCIA', 'DESCRIPCION_CANTON',
#        'DESCRIPCION_PARROQUIA', 'CODIGO_CIIU', 'ACTIVIDAD_ECONOMICA'],
#       dtype='object')

# %%
df = guayaquil.dropna(subset=['FECHA_INICIO_ACTIVIDADES'])

# %%
df.head()
# Out:
#       NUMERO_RUC                                 RAZON_SOCIAL  \
# ID
# 0   100087626001  MOSCOSO HEREDIA RUTH ESTHELA DE LOS ANGELES
# 1   100081728001                  QUITO TENEMASA LUIS ANTONIO
# 2   100086859001                LLIVISACA NAUTA MARIA ROSARIO
# 3   100123975001               RODAS MORALES RAQUEL DEL PILAR
# 4   100122753001               AGUILERA TORAL MIGUEL PATRICIO
#
#            NOMBRE_COMERCIAL ESTADO_CONTRIBUYENTE CLASE_CONTRIBUYENTE  \
# ID
# 0                       NaN               ACTIVO               OTROS
# 1   VULCANIZADORA MAGDALENA           SUSPENDIDO               OTROS
# 2                       NaN           SUSPENDIDO               OTROS
# 3                       NaN               ACTIVO               OTROS
# 4                       NaN               ACTIVO               OTROS
#
#    FECHA_INICIO_ACTIVIDADES FECHA_ACTUALIZACION FECHA_SUSPENSION_DEFINITIVA  \
# ID
# 0                11/04/2001          20/09/2011                         NaN
# 1                18/05/1973          17/04/2001                  13/09/2006
# 2                17/10/1996          09/04/2002                  31/12/2001
# 3                12/10/1992          14/07/2015                  16/01/2002
# 4                28/06/1985          17/07/2017                         NaN
#
#    FECHA_REINICIO_ACTIVIDADES OBLIGADO  ... NOMBRE_FANTASIA_COMERCIAL  \
# ID                                      ...
# 0                         NaN        N  ...                       NaN
# 1                         NaN        N  ...   VULCANIZADORA MAGDALENA
# 2                         NaN        N  ...                       NaN
# 3                  16/05/2003        N  ...                       NaN
# 4                         NaN        S  ...     ELECTRONICA LOS ANDES
#
#                   CALLE   NUMERO      INTERSECCION ESTADO_ESTABLECIMIENTO  \
# ID
# 0             AV. PARIS  N40-177          GRANADOS                    ABI
# 1               CANARIS      424         DUCHICELA                    CER
# 2             RIO NUEVO      S/N         PORTOVELO                    CER
# 3   ANTONIO DE MARCHENA   OE1-71  AV. 10 DE AGOSTO                    ABI
# 4      AV. 10 DE AGOSTO      520             CHECA                    CER
#
#    DESCRIPCION_PROVINCIA DESCRIPCION_CANTON DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 0              PICHINCHA              QUITO              IÑAQUITO     L682002
# 1              PICHINCHA              QUITO          LA MAGDALENA     G452001
# 2              PICHINCHA              QUITO           CHILLOGALLO     I563002
# 3              PICHINCHA              QUITO              SAN JUAN     P854994
# 4              PICHINCHA              QUITO              IÑAQUITO     G469000
#
#                                   ACTIVIDAD_ECONOMICA
# ID
# 0   INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 1   MANTENIMIENTO Y REPARACIÓN DE VEHÍCULOS AUTOMO...
# 2   ACTIVIDADES DE PREPARACIÓN Y SERVICIO DE BEBID...
# 3                     OTROS TIPOS DE ENSEÑANZA N.C.P.
# 4   VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...
#
# [5 rows x 22 columns]

# %%
df['FECHA_INICIO_ACTIVIDADES'] = pd.to_datetime(df['FECHA_INICIO_ACTIVIDADES'])
df['fecha_ano'] = df['FECHA_INICIO_ACTIVIDADES'].dt.year
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# solo consideramos para nuestro analisis desde 1998
df_anos = df[ (1998 <=df['fecha_ano']) & (df['fecha_ano']<=2018) ]

# %% [markdown]
# ## total de contribuyentes por año desde 1998 hasta 2018

# %%
# total de contribuyente para este analisis
total = float(len(df_anos))
total
# Out:
# 1033788.0

# %%
tabla_x_ano = df_anos.groupby("fecha_ano").count()
tabla_x_ano["NUMERO_RUC"]
# Out:
# fecha_ano
# 1998    25935
# 1999    46213
# 2000    47521
# 2001    45930
# 2002    68274
# 2003    43791
# 2004    42926
# 2005    43580
# 2006    45129
# 2007    40466
# 2008    53358
# 2009    50513
# 2010    54925
# 2011    46879
# 2012    50990
# 2013    56180
# 2014    46891
# 2015    44318
# 2016    46149
# 2017    63970
# 2018    69850
# Name: NUMERO_RUC, dtype: int64

# %%
#nuevos contribuyentes
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='fecha_ano', data=df_anos,color=COLOR)
ax.set(ylabel='CANTIDAD DE NUEVOS CONTRIBUYENTES', xlabel="AÑO",title='Nuevos Contribuyentes por año')
total = float(len(df_anos))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f} %'.format((height/total) * 100),
            ha="center")

# %%
#contribuyentes por año deacuerdo a su estado
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='fecha_ano', data=df_anos, hue="ESTADO_CONTRIBUYENTE",palette=sns.color_palette("Set1", n_colors=3, desat=.5))
ax.set(ylabel='CANTIDAD DE CONTRIBUYENTES', xlabel="AÑO",title='Contribuyentes por año categorizados por el respectivo estado actual del contribuyente')
total = float(len(df_anos))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f} %'.format((height/total) * 100),
            ha="center")

# %%
plt.figure(figsize=(16, 6))
ax = sns.catplot(x="fecha_ano", data=df_anos, color=COLOR,row="ESTADO_CONTRIBUYENTE",kind="count",height=5, aspect=4)
total = float(len(df_anos))

# %%
def por_mes(ano):
    plt.figure(figsize=(16, 6))
    df_x = df_anos[df_anos['fecha_ano']==ano ]
    ax = sns.countplot(x='fecha_mes', data=df_x,color=COLOR,order=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"])
    ax.set(ylabel='CANTIDAD DE NUEVOS CONTRIBUYENTES', xlabel="MES",title='Nuevos Contribuyentes ' + str(ano),ylim=(0, 18500))
    total = float(len(df_x))
    for p in ax.patches:
        print(p.get_height())
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
        height + 3,
        '{:1.2f} %'.format((height/total) * 100),
        ha="center")
    plt.savefig("CONTRIBUYENTES_X_MES_"+str(ano)+".png")
def mapper(month):
    return month.strftime('%b') 
df_anos['fecha_mes'] = df_anos['FECHA_INICIO_ACTIVIDADES'].apply(mapper)
for ano in df_anos['fecha_ano'].unique().tolist():
    por_mes(ano)
#convert -delay 30 *.png animated_chart.gif
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 3953
# 3098
# 4244
# 3474
# 4196
# 3893
# 3792
# 4259
# 3877
# 4103
# 4042
# 2999
# 9691
# 11377
# 6069
# 5549
# 5483
# 5016
# 4483
# 4963
# 3709
# 4155
# 4556
# 3223
# 3892
# 3475
# 4050
# 3444
# 3866
# 3470
# 3876
# 3686
# 3631
# 4403
# 3441
# 2557
# 3584
# 2870
# 4133
# 3225
# 3478
# 2953
# 3120
# 3570
# 3231
# 3534
# 3744
# 3024
# 3712
# 3058
# 3467
# 3705
# 3701
# 3706
# 3692
# 3694
# 3784
# 3649
# 3370
# 3388
# 8400
# 1475
# 2441
# 2599
# 1520
# 1115
# 1531
# 1185
# 1481
# 1574
# 1450
# 1164
# 4009
# 2183
# 2440
# 2806
# 3190
# 3792
# 5262
# 5243
# 5182
# 5235
# 3691
# 3180
# 3970
# 3562
# 4664
# 3886
# 4161
# 3930
# 3895
# 4139
# 3828
# 4524
# 3990
# 2972
# 3610
# 2785
# 4192
# 3432
# 4358
# 4839
# 3685
# 3951
# 3605
# 3814
# 3822
# 3036
# 4220
# 2999
# 3501
# 3873
# 3678
# 3735
# 3819
# 3437
# 3709
# 3785
# 3933
# 2891
# 4961
# 4397
# 4219
# 4417
# 4134
# 3806
# 4409
# 4405
# 4992
# 5161
# 4868
# 3589
# 4390
# 3332
# 4616
# 5143
# 4854
# 4536
# 4884
# 4751
# 4995
# 4914
# 4332
# 4178
# 4379
# 3367
# 4700
# 4306
# 4709
# 4551
# 4227
# 3948
# 4624
# 4308
# 3949
# 3445
# 5349
# 4016
# 4596
# 3349
# 3743
# 3443
# 3923
# 3707
# 3413
# 4595
# 3952
# 2805
# 4440
# 3178
# 4454
# 3614
# 4059
# 4444
# 4473
# 4346
# 4020
# 4485
# 18783
# 3674
# 4770
# 4951
# 4575
# 5004
# 5152
# 4244
# 4763
# 4931
# 4490
# 5088
# 4774
# 3438
# 3586
# 2837
# 3905
# 3460
# 4245
# 4417
# 4307
# 4332
# 4266
# 4016
# 4068
# 3440
# 3831
# 3688
# 4786
# 4084
# 4572
# 4499
# 4505
# 4688
# 4464
# 4346
# 4409
# 3118
# 4371
# 4552
# 5045
# 17933
# 5433
# 4912
# 4299
# 5032
# 4865
# 4730
# 4856
# 3822
# 3725
# 3172
# 3563
# 4089
# 3802
# 3784
# 3766
# 3743
# 4065
# 4142
# 3477
# 2990
# 4119
# 3747
# 3613
# 3772
# 3877
# 3765
# 3937
# 4037
# 3966
# 3742
# 3903
# 3671

# %%
poblacion_x = pd.read_csv("Proyecto/factorNormalizacionQUITO.csv" ,sep=",",encoding ="utf-8",error_bad_lines=False)
poblacion_x
# Out:
#            DESCRIPCION_PARROQUIA  POBLACION    AREA    FACTOR  TOTAL_LOCALES
# 0                       ALANGASI      25477   29.43  0.427837          10900
# 1                       AMAGUAÑA      34812   56.30  0.257584           8967
# 2         ATAHUALPA (HABASPAMBA)       2755   70.18  0.198185            546
# 3                       CALACALI       5363  190.22  0.227485           1220
# 4           CALDERON (CARAPUNGO)     125364   78.89  0.495677          62140
# 5                       CARCELÉN      54978     NaN  0.695369          38230
# 6                    CHAVEZPAMBA       1276   12.31  0.137931            176
# 7                 CHECA (CHILPA)      10926   89.56  0.177467           1939
# 8               CENTRO HISTÓRICO      54678     NaN  1.482991          81087
# 9                    CHILLOGALLO      63771     NaN  1.512051          96425
# 10                   CHIMBACALLE      47722     NaN  0.977537          46650
# 11             COMITÉ DEL PUEBLO      57893     NaN  0.094226           5455
# 12                      CONOCOTO      78149   38.63  0.560698          43818
# 13                    COTOCOLLAO      49865     NaN  2.105806         105006
# 14                       CUMBAYA      31178   21.12  0.985663          30731
# 15                    EL CONDADO      81043     NaN  0.033538           2718
# 16                    EL QUINCHE      19082   74.69  0.265276           5062
# 17                        GUALEA       3136  120.86  0.145408            456
# 18                       GUAMANÍ      57205     NaN  0.484800          27733
# 19                    GUANGOPOLO       3365   10.19  0.280832            945
# 20                  GUAYLLABAMBA      18060   55.44  0.276689           4997
# 21                     ITCHIMBIA      50903     NaN  0.203760          10372
# 22                      IÑAQUITO      50121     NaN  2.386624         119620
# 23                      JIPIJAPA      39627     NaN  0.100815           3995
# 24                       KENNEDY      79987     NaN  0.484829          38780
# 25                    LA ARGELIA      53894     NaN  0.048818           2631
# 26                 LA CONCEPCIÓN      42080     NaN  2.504111         105373
# 27                LA ECUATORIANA      62731     NaN  0.030718           1927
# 28                LA FERROVIARIA      74357     NaN  0.029600           2201
# 29                   LA LIBERTAD      33388     NaN  0.113065           3775
# ..                           ...        ...     ...       ...            ...
# 35                MARISCAL SUCRE      20430     NaN  1.022173          20883
# 36                       NANEGAL       3699  245.77  0.194918            721
# 37                    NANEGALITO       3637  124.67  0.359087           1306
# 38                         NAYON      14277   16.11  0.405687           5792
# 39                          NONO       2589  214.28  0.137505            356
# 40                         PACTO       7099  347.16  0.195661           1389
# 41                       PERUCHO       1108    9.80  0.175993            195
# 42                          PIFO      18298  254.44  0.380042           6954
# 43                        PINTAG      21360  490.49  0.236236           5046
# 44                      PONCEANO      52257     NaN  0.056662           2961
# 45                      PUELLARO       8409   70.93  0.131169           1103
# 46                        PUEMBO      16140   31.77  0.335626           5417
# 47  QUITO DISTRITO METROPOLITANO    1619146  372.39  0.016533          26769
# 48                      QUITUMBE      61896     NaN  0.183049          11330
# 49                     RUMIPAMBA      36543     NaN  0.101552           3711
# 50                   SAN ANTONIO      29338  111.41  0.448088          13146
# 51                   SAN BARTOLO      68711     NaN  0.050327           3458
# 52           SAN ISIDRO DEL INCA      38366     NaN  0.138795           5325
# 53                      SAN JUAN      60157     NaN  1.576126          94815
# 54             SAN JOSE DE MINAS      11094  308.00  0.095457           1059
# 55                       SOLANDA      99765     NaN  0.034210           3413
# 56                      TABABELA       3397   25.33  0.513100           1743
# 57                     TURUBAMBA      52567     NaN  0.284304          14945
# 58                       TUMBACO      56947   65.25  0.509807          29032
# 59                       YARUQUI      20345   71.95  0.275154           5598
# 60                       ZAMBIZA       4186    7.41  0.431916           1808
# 61                     CHILIBULO      49025     NaN  0.022213           1089
# 62             BELISARIO QUEVEDO      48324     NaN  0.136826           6612
# 63                    COCHAPAMBA      58004     NaN  0.050652           2938
# 64                      PUENGASÍ      32345     NaN  0.081342           2631
#
# [65 rows x 5 columns]

# %%
def por_ano_parroquia(ano):
    df_x = df_anos[df_anos['fecha_ano']==ano]
    df_x_parroquia = df_x.groupby(["DESCRIPCION_PARROQUIA"]).count().reset_index()
    df_x_parroquia = df_x_parroquia[["DESCRIPCION_PARROQUIA","NUMERO_RUC"]]
    resultado = pd.merge(left=df_x_parroquia,right=poblacion_x, left_on='DESCRIPCION_PARROQUIA', right_on='DESCRIPCION_PARROQUIA',suffixes=("",""))
    resultado["cantidadNormalizada"] = resultado["NUMERO_RUC"] * resultado["FACTOR"]
    print(resultado["cantidadNormalizada"].max())
    resultado = resultado[["DESCRIPCION_PARROQUIA","cantidadNormalizada"]]
    resultado.to_csv("parroquias_"+str(ano)+".csv", header=True, encoding="utf-8", index=False)
for ano in df_anos['fecha_ano'].unique().tolist():
    por_ano_parroquia(ano)
#convert -delay 30 *.png animated_chart.gif # MAXIMO 22000
# Out:
# 14404.557979458552
# 21760.34356792499
# 13251.692095065175
# 13210.965854583887
# 12957.21004850817
# 6578.85423159264
# 13422.036121673005
# 14120.683151140685
# 15563.689439310589
# 13295.551123275793
# 16738.484837809272
# 18348.737730684807
# 16829.335681959838
# 14564.330153654373
# 14501.674399067777
# 19294.839624942415
# 16375.081461207013
# 17631.329340668275
# 10859.140879072642
# 12142.685238882415
# 12819.367388417659

# %%
df_parroquias = df_anos
df_parroquias["cantidad"] = df_parroquias.groupby(["fecha_ano","DESCRIPCION_PARROQUIA"])["NUMERO_RUC"].transform(lambda x : x.count())
df_x_parroquia = df_parroquias[["DESCRIPCION_PARROQUIA","fecha_ano","FECHA_INICIO_ACTIVIDADES","cantidad"]]
df_x_parroquia.drop_duplicates(subset=["DESCRIPCION_PARROQUIA","fecha_ano","FECHA_INICIO_ACTIVIDADES"]).to_csv("por_parroquiasGuayaquil.csv", header=True, encoding="utf-8", index=False)
df_parroquias
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             NUMERO_RUC                                       RAZON_SOCIAL  \
# ID
# 0         100087626001        MOSCOSO HEREDIA RUTH ESTHELA DE LOS ANGELES
# 10        100149590001                    ORDONEZ ORDONEZ SERGIO CLOTARIO
# 13        100291509001                          ARGUDO ROMERO JULIO MARIA
# 15        100317684001                     GUZMAN DE LA BASTIDA ANA MARIA
# 18        100011113001                     CEVALLOS FAJARDO LIGIA BRIGIDA
# 19        100021120001                                 PEÑA UGALDE GENARO
# 21        100040088001                     GRANDA UGALDE EDMUNDO HUMBERTO
# 22        100040146001  JERVES VAZQUEZ AUGUSTO NICOLAS RICARDO PORFIRIO M
# 23        100133388001                          REYES CADENA FANNY ALICIA
# 29        100081702001                        ELJURI CORDERO GABRIEL JOSE
# 31        100107275001                          HIDALGO CELI NELO AUGUSTO
# 32        100135169001                          CHUCHUCA BRITO JAIME RAUL
# 33        100143338001                      PERALTA BACUILIMA MANUEL CRUZ
# 34        100157148001                     CARVAJAL SIGCHA ADRIAN MARCELO
# 35        100178201001                    ALVAREZ PACHECO CLAUDIO EUGENIO
# 36        100194364001                         DELEG DUQUE MIGUEL ANTONIO
# 37        100209170001                     GALAN PRIETO MARIANA ORFELINDA
# 40        100300516001                        PINEDA OROSCO COLON ENRIQUE
# 41        100342088001                          SAA UTRERAS MARIA MARIANA
# 42        100331958001                          JIMA VEGA JOSE FLORENTINO
# 52        100060334001                       GUERRERO VARGAS EDGAR HERNAN
# 56        100055508001                         RUBIO NARANJO JOSE SEGUNDO
# 57        100043223001                          MORAN ERAZO LUIS HUMBERTO
# 58        100035427001                  VANEGAS CORONEL BENJAMIN HERMINIO
# 59        100037654001                PEÑAHERRERA CARDENAS MANUEL OCTAVIO
# 60        100039825001                   YUNGA TENESACA ALFONSO AURELIANO
# 61        100085877001                     BERNAL BARZALLO WALTER GERARDO
# 62        100085877001                     BERNAL BARZALLO WALTER GERARDO
# 65        100139799001                     LLIVISACA MURILLO VICTOR MARIA
# 66        100125293001               VINTIMILLA VINTIMILLA MARTHA EULALIA
# ...                ...                                                ...
# 1423262  1726339839001                          GARCIA PILCA BRYAN MARTIN
# 1423263  1726431982001                  GARCIA VELASQUEZ LIZETH ESTEFANIA
# 1423264  1726499716001                              ROJAS MERA LUIS DAVID
# 1423265  1726544321001                    IBARRA CORDOBA ADRIANA CAROLINA
# 1423266  1726601089001                ZAMBRANO TORRES PRISCILLA DEL CISNE
# 1423267  1726846452001                          OCAMPO AGUIRRE BRYAN JOEL
# 1423268  1726924218001                         GONZALEZ COYAGO ROSA LUCIA
# 1423269  1727381350001                     COAMACAS CASTRO LUIS GUILLERMO
# 1423270  1727408419001                   GRANDA CASTILLO JEFFERSON RAMIRO
# 1423271  1727429431001                       ALQUINGA POZO GENESIS NATALY
# 1423272  1727520932001                         ARMAS USUAY ROSA GUADALUPE
# 1423273  1729355980001                      MONTES PARRAGA JHON SEBASTIAN
# 1423293  1309344222001                        CELI ABEIGA RICARDO ALFONSO
# 1423296  1758088064001                        CAMEJO ROJAS JUAN ALEJANDRO
# 1423297  1758549289001                          MARCANO TORRES MARINELLYS
# 1423304  1758853053001                  MONTERO ASCANIO KATHLEEN PATRICIA
# 1423307  1759011024001                        CASTILLO NAVA EDWIN GABRIEL
# 1423326  1753373560001                    BERNAL CARDENAS ANDREA CAROLINA
# 1423327  1754173415001                             TARASIUK MARISA BLANCA
# 1423332  1757244593001                    ESPINOZA MARTINEZ YAVET D JESUS
# 1423352  1754579009001            HUMPIERRES ATTAS JONATHAN DARIO VALERIO
# 1423378  1750218461001                TENEMAZA ALBARRACIN VANESSA VALERIA
# 1423393  1727120972001                      JARAMILLO ESCORCIA ANNY SARAI
# 1423413  1757810351001                         OSUNA SANTIAGO DANY DANIEL
# 1423416   962768388001                       GUERRERO DE ARELLANO YESENIA
# 1423417   962768388001                       GUERRERO DE ARELLANO YESENIA
# 1423419   950255414001                   SORIANO ARECHUA ANGELI MAGDALENA
# 1423443   502264088001                    PAZMIÑO CASTELLANO MARIA ISABEL
# 1423445   502913015001                       CHICAIZA TONATO NORMA XIMENA
# 1423447  1203358286001                 GARCIA CRUZ MARTIRE DE LOS ANGELES
#
#                           NOMBRE_COMERCIAL ESTADO_CONTRIBUYENTE  \
# ID
# 0                                      NaN               ACTIVO
# 10                                     NaN               ACTIVO
# 13                                     NaN               ACTIVO
# 15                                     NaN               ACTIVO
# 18                                     NaN           SUSPENDIDO
# 19                                     NaN           SUSPENDIDO
# 21                                     NaN           SUSPENDIDO
# 22                                     NaN               PASIVO
# 23                                     NaN           SUSPENDIDO
# 29                                     NaN           SUSPENDIDO
# 31       HOTEL SUMAQ KAY CUMBAYA - ECUADOR               ACTIVO
# 32                                     NaN               ACTIVO
# 33                         VIVERES PABLITO           SUSPENDIDO
# 34                                   DAERA               ACTIVO
# 35                                     NaN           SUSPENDIDO
# 36                                     NaN           SUSPENDIDO
# 37                                 MARISOL           SUSPENDIDO
# 40                            COLON PINEDA           SUSPENDIDO
# 41                                     NaN           SUSPENDIDO
# 42                                     NaN               ACTIVO
# 52                                     NaN           SUSPENDIDO
# 56                                     NaN               ACTIVO
# 57                                     NaN               PASIVO
# 58                                     NaN           SUSPENDIDO
# 59                                     NaN           SUSPENDIDO
# 60                                     NaN               PASIVO
# 61                                     NaN               ACTIVO
# 62                                     NaN               ACTIVO
# 65                             LA LOJANITA           SUSPENDIDO
# 66                       PANADERIA MODERNA           SUSPENDIDO
# ...                                    ...                  ...
# 1423262                                NaN               ACTIVO
# 1423263                                NaN               ACTIVO
# 1423264                                NaN               ACTIVO
# 1423265                                NaN               ACTIVO
# 1423266                                NaN               ACTIVO
# 1423267                                NaN               ACTIVO
# 1423268                                NaN               ACTIVO
# 1423269                                NaN               ACTIVO
# 1423270                                NaN               ACTIVO
# 1423271                                NaN               ACTIVO
# 1423272                                NaN               ACTIVO
# 1423273                                NaN               ACTIVO
# 1423293                                NaN           SUSPENDIDO
# 1423296                                NaN               ACTIVO
# 1423297                                NaN               ACTIVO
# 1423304                                NaN               ACTIVO
# 1423307                     V&G PELUQUERIA               ACTIVO
# 1423326                                NaN               ACTIVO
# 1423327                                NaN               ACTIVO
# 1423332                                NaN               ACTIVO
# 1423352                                NaN               ACTIVO
# 1423378                                NaN               ACTIVO
# 1423393                                NaN               ACTIVO
# 1423413                                NaN               ACTIVO
# 1423416                       AREPAZO CAFE               ACTIVO
# 1423417                       AREPAZO CAFE               ACTIVO
# 1423419                                NaN               ACTIVO
# 1423443        SASTRERIA Y MODAS ISABELITA           SUSPENDIDO
# 1423445                                NaN           SUSPENDIDO
# 1423447                                NaN           SUSPENDIDO
#
#         CLASE_CONTRIBUYENTE FECHA_INICIO_ACTIVIDADES FECHA_ACTUALIZACION  \
# ID
# 0                     OTROS               2001-11-04          20/09/2011
# 10                    OTROS               2002-02-14          16/11/2009
# 13                    OTROS               2001-09-28          15/05/2017
# 15                    OTROS               2001-04-25          30/01/2008
# 18                    OTROS               2003-09-24          24/09/2003
# 19                    OTROS               2001-09-13          02/08/2017
# 21                    OTROS               2002-04-29                 NaN
# 22                    OTROS               2007-04-19          01/09/2010
# 23                    OTROS               2002-10-14                 NaN
# 29                    OTROS               2002-01-29          23/05/2017
# 31                    OTROS               2004-04-08          30/06/2015
# 32                    OTROS               1998-04-27          22/03/2018
# 33                    OTROS               1999-07-06          15/02/2001
# 34                    OTROS               2000-09-25          22/06/2011
# 35                    OTROS               2002-11-18          18/01/2013
# 36                    OTROS               2003-03-19          28/03/2003
# 37                    OTROS               2000-06-10                 NaN
# 40                    OTROS               1999-11-16          16/11/1999
# 41                    OTROS               2000-11-17                 NaN
# 42                    OTROS               2000-08-03          30/07/2018
# 52                    OTROS               2001-08-05          26/07/2002
# 56                    OTROS               2000-06-06          22/11/2010
# 57                    OTROS               2001-02-05          27/07/2009
# 58                    OTROS               2006-03-28          01/07/2011
# 59                    OTROS               2002-11-04          26/09/2012
# 60                    OTROS               2001-02-23          23/02/2005
# 61                    OTROS               1999-10-09          24/06/2016
# 62                    OTROS               1999-10-09          24/06/2016
# 65                    OTROS               2004-12-07                 NaN
# 66                    OTROS               2000-05-15          30/07/2004
# ...                     ...                      ...                 ...
# 1423262               OTROS               2018-10-12                 NaN
# 1423263                RISE               2018-10-12                 NaN
# 1423264               OTROS               2018-10-31                 NaN
# 1423265               OTROS               2018-05-03          15/11/2018
# 1423266                RISE               2018-10-12                 NaN
# 1423267               OTROS               2018-10-12                 NaN
# 1423268               OTROS               2018-10-12                 NaN
# 1423269                RISE               2018-10-12                 NaN
# 1423270                RISE               2018-10-12                 NaN
# 1423271               OTROS               2018-10-12                 NaN
# 1423272               OTROS               2018-11-14                 NaN
# 1423273               OTROS               2018-12-11                 NaN
# 1423293               OTROS               2016-09-13                 NaN
# 1423296               OTROS               2015-12-03          19/01/2019
# 1423297               OTROS               2018-03-09                 NaN
# 1423304               OTROS               2017-10-18          09/01/2019
# 1423307               OTROS               2018-01-29          28/01/2019
# 1423326               OTROS               2018-04-09          10/01/2019
# 1423327               OTROS               2018-04-09          27/09/2018
# 1423332               OTROS               2016-01-06          10/01/2019
# 1423352               OTROS               2011-07-22          16/01/2019
# 1423378               OTROS               2018-08-14                 NaN
# 1423393               OTROS               2018-10-24                 NaN
# 1423413               OTROS               2016-05-26                 NaN
# 1423416               OTROS               2018-05-18          10/01/2019
# 1423417               OTROS               2018-05-18          10/01/2019
# 1423419               OTROS               2018-11-14          12/12/2018
# 1423443               OTROS               2006-03-27          16/10/2017
# 1423445               OTROS               2018-07-27                 NaN
# 1423447               OTROS               2017-05-29                 NaN
#
#         FECHA_SUSPENSION_DEFINITIVA FECHA_REINICIO_ACTIVIDADES OBLIGADO  ...  \
# ID                                                                       ...
# 0                               NaN                        NaN        N  ...
# 10                       11/08/2003                 11/08/2003        N  ...
# 13                              NaN                        NaN        N  ...
# 15                              NaN                 30/01/2008        N  ...
# 18                       20/08/2004                        NaN        N  ...
# 19                       15/08/2017                 02/08/2017        N  ...
# 21                       13/09/2006                        NaN        N  ...
# 22                       25/08/2011                        NaN        N  ...
# 23                       18/05/2009                        NaN        N  ...
# 29                       27/07/2018                 23/05/2017        N  ...
# 31                              NaN                 30/06/2015        N  ...
# 32                              NaN                        NaN        S  ...
# 33                       30/11/2000                        NaN        N  ...
# 34                              NaN                 08/07/2010        N  ...
# 35                       13/06/2013                        NaN        N  ...
# 36                       31/08/2011                        NaN        N  ...
# 37                       13/09/2006                        NaN        N  ...
# 40                       31/08/2011                        NaN        N  ...
# 41                       13/09/2006                        NaN        N  ...
# 42                       08/01/2004                 07/06/2004        N  ...
# 52                       10/01/2014                        NaN        N  ...
# 56                              NaN                 14/10/2008        N  ...
# 57                       28/12/2010                        NaN        N  ...
# 58                       11/05/2016                        NaN        N  ...
# 59                       16/04/2014                        NaN        N  ...
# 60                       23/09/2008                        NaN        N  ...
# 61                              NaN                        NaN        N  ...
# 62                              NaN                        NaN        N  ...
# 65                       11/01/2017                        NaN        N  ...
# 66                       18/12/2007                        NaN        S  ...
# ...                             ...                        ...      ...  ...
# 1423262                         NaN                        NaN        N  ...
# 1423263                         NaN                        NaN        N  ...
# 1423264                         NaN                        NaN        N  ...
# 1423265                         NaN                 15/11/2018        N  ...
# 1423266                         NaN                        NaN        N  ...
# 1423267                         NaN                        NaN        N  ...
# 1423268                         NaN                        NaN        N  ...
# 1423269                         NaN                        NaN        N  ...
# 1423270                         NaN                        NaN        N  ...
# 1423271                         NaN                        NaN        N  ...
# 1423272                         NaN                        NaN        N  ...
# 1423273                         NaN                        NaN        N  ...
# 1423293                  25/01/2019                        NaN        N  ...
# 1423296                         NaN                        NaN        N  ...
# 1423297                         NaN                        NaN        N  ...
# 1423304                         NaN                        NaN        N  ...
# 1423307                         NaN                        NaN        N  ...
# 1423326                         NaN                 10/01/2019        N  ...
# 1423327                         NaN                 27/09/2018        N  ...
# 1423332                         NaN                 10/01/2019        N  ...
# 1423352                         NaN                        NaN        N  ...
# 1423378                         NaN                        NaN        N  ...
# 1423393                         NaN                        NaN        N  ...
# 1423413                         NaN                        NaN        N  ...
# 1423416                         NaN                        NaN        N  ...
# 1423417                         NaN                        NaN        N  ...
# 1423419                         NaN                        NaN        N  ...
# 1423443                  08/02/2019                 16/10/2017        N  ...
# 1423445                  08/02/2019                        NaN        N  ...
# 1423447                  07/02/2019                        NaN        N  ...
#
#                 INTERSECCION  ESTADO_ESTABLECIMIENTO DESCRIPCION_PROVINCIA  \
# ID
# 0                   GRANADOS                     ABI             PICHINCHA
# 10                   MACHALA                     ABI             PICHINCHA
# 13              LOS CIPRESES                     ABI             PICHINCHA
# 15           AV. ELOY ALFARO                     ABI             PICHINCHA
# 18       AVENIDA ELOY ALFARO                     CER             PICHINCHA
# 19                SECUNDARIA                     CER             PICHINCHA
# 21                    BRASIL                     CER             PICHINCHA
# 22               RIO CURARAY                     CER             PICHINCHA
# 23                       NaN                     CER             PICHINCHA
# 29                  EL BATAN                     CER             PICHINCHA
# 31                       NaN                     ABI             PICHINCHA
# 32               EL VENGADOR                     CER             PICHINCHA
# 33                BUSTAMANTE                     CER             PICHINCHA
# 34                   CALLE K                     ABI             PICHINCHA
# 35            VIA AL QUINCHE                     CER             PICHINCHA
# 36            LOS GUAYACANES                     CER             PICHINCHA
# 37                       NaN                     CER             PICHINCHA
# 40                LAS MALVAS                     CER             PICHINCHA
# 41               PEDRO BOTTO                     CER             PICHINCHA
# 42                       NaN                     ABI             PICHINCHA
# 52          AV. ISIDRO AYORA                     CER             PICHINCHA
# 56                       S/N                     ABI             PICHINCHA
# 57                ANDAGUIRRE                     CER             PICHINCHA
# 58              ANGEL LUDEÑA                     CER             PICHINCHA
# 59             MANUEL MATHEU                     CER             PICHINCHA
# 60                   CALLE H                     CER             PICHINCHA
# 61           NAZACOTA PUENTO                     ABI             PICHINCHA
# 62        JOSE MARIA BORRERO                     ABI             PICHINCHA
# 65                     HUACA                     CER             PICHINCHA
# 66                  ALEMANIA                     CER             PICHINCHA
# ...                      ...                     ...                   ...
# 1423262            HERNANDEZ                     ABI             PICHINCHA
# 1423263      BARTOLOME ALVEZ                     ABI             PICHINCHA
# 1423264             PASAJE E                     ABI             PICHINCHA
# 1423265           CONDOR ÑAN                     ABI             PICHINCHA
# 1423266                  NaN                     ABI             PICHINCHA
# 1423267                  NaN                     ABI             PICHINCHA
# 1423268       4 DE NOVIEMBRE                     ABI             PICHINCHA
# 1423269           ESCALINATA                     ABI             PICHINCHA
# 1423270           CALLE S29C                     ABI             PICHINCHA
# 1423271                   SN                     ABI             PICHINCHA
# 1423272         LA MAGDALENA                     ABI             PICHINCHA
# 1423273         JOSE HERBOSO                     ABI             PICHINCHA
# 1423293           GUAYACANES                     CER             PICHINCHA
# 1423296          AV AMAZONAS                     ABI             PICHINCHA
# 1423297                  NaN                     ABI             PICHINCHA
# 1423304    AV. INTEROCEANICA                     ABI             PICHINCHA
# 1423307             PORTUGAL                     ABI             PICHINCHA
# 1423326        ISLA FLOREANA                     ABI             PICHINCHA
# 1423327                  NaN                     ABI             PICHINCHA
# 1423332            RUMIPAMBA                     ABI             PICHINCHA
# 1423352       DE LOS CAFETOS                     ABI             PICHINCHA
# 1423378            CALLE S53                     ABI             PICHINCHA
# 1423393       DE LOS FRESNOS                     ABI             PICHINCHA
# 1423413         LINEA FERREA                     ABI             PICHINCHA
# 1423416   DE LOS HEMISFERIOS                     ABI             PICHINCHA
# 1423417               EL SOL                     ABI             PICHINCHA
# 1423419                  NaN                     ABI             PICHINCHA
# 1423443         PASAJE OE9-H                     CER             PICHINCHA
# 1423445         LAS CIGUEÑAS                     CER             PICHINCHA
# 1423447    OE4 RUMICHACA ÑAN                     CER             PICHINCHA
#
#         DESCRIPCION_CANTON         DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 0                    QUITO                      IÑAQUITO     L682002
# 10                   QUITO                    COTOCOLLAO     L682002
# 13                   QUITO                       TUMBACO     M702003
# 15                   QUITO                    COTOCOLLAO     L682002
# 18                   QUITO                    COTOCOLLAO     B081014
# 19                   QUITO                         NAYON     M691009
# 21                   QUITO                 LA CONCEPCIÓN     P853002
# 22                   QUITO                      ALANGASI     L682002
# 23                   QUITO                       KENNEDY     I551009
# 29                   QUITO                      IÑAQUITO     L682002
# 31                   QUITO                       CUMBAYA     I551001
# 32                   QUITO  QUITO DISTRITO METROPOLITANO     H492101
# 33                   QUITO                 LA CONCEPCIÓN     G471101
# 34                   QUITO                       GUAMANÍ     C162914
# 35                   QUITO                  GUAYLLABAMBA     P853002
# 36                   QUITO                    COTOCOLLAO     I561002
# 37                   QUITO          CALDERON (CARAPUNGO)     G477205
# 40                   QUITO                 LA CONCEPCIÓN     M702003
# 41                   QUITO                    COTOCOLLAO     M749010
# 42                   QUITO                   CHILLOGALLO     H492205
# 52                   QUITO                      CARCELÉN     Q862002
# 56                   QUITO                    COTOCOLLAO     G477205
# 57                   QUITO                    COTOCOLLAO     P853002
# 58                   QUITO                    COTOCOLLAO     W200000
# 59                   QUITO                 LA CONCEPCIÓN     H492204
# 60                   QUITO                     TURUBAMBA     H492202
# 61                   QUITO                      CARCELÉN     M711022
# 62                   QUITO                 LA CONCEPCIÓN     M711022
# 65                   QUITO                  LA MAGDALENA     G471101
# 66                   QUITO                      IÑAQUITO     G472105
# ...                    ...                           ...         ...
# 1423262              QUITO  QUITO DISTRITO METROPOLITANO     S960907
# 1423263              QUITO                   CHIMBACALLE     S960907
# 1423264              QUITO                   SAN ANTONIO     S960907
# 1423265              QUITO                      QUITUMBE     G472202
# 1423266              QUITO                      AMAGUAÑA     S960907
# 1423267              QUITO                     TURUBAMBA     G463095
# 1423268              QUITO                       YARUQUI     G463012
# 1423269              QUITO                      PUENGASÍ     C141004
# 1423270              QUITO                   CHILLOGALLO     F410010
# 1423271              QUITO                        PINTAG     A014601
# 1423272              QUITO          CALDERON (CARAPUNGO)     S960907
# 1423273              QUITO          CALDERON (CARAPUNGO)     S960907
# 1423293              QUITO                       KENNEDY     M749010
# 1423296              QUITO                      IÑAQUITO     S960907
# 1423297              QUITO             COMITÉ DEL PUEBLO     M749010
# 1423304              QUITO                       CUMBAYA     M749010
# 1423307              QUITO                      IÑAQUITO     S960200
# 1423326              QUITO                      JIPIJAPA     M749010
# 1423327              QUITO                       CUMBAYA     L682002
# 1423332              QUITO                     RUMIPAMBA     Q862001
# 1423352              QUITO                       CUMBAYA     S960907
# 1423378              QUITO                     TURUBAMBA     M692009
# 1423393              QUITO                       KENNEDY     M749010
# 1423413              QUITO                   CHILLOGALLO     M749010
# 1423416              QUITO                   SAN ANTONIO     I561001
# 1423417              QUITO                   SAN ANTONIO     I561001
# 1423419              QUITO                   SAN BARTOLO     S960907
# 1423443              QUITO                  LA MAGDALENA     C141004
# 1423445              QUITO          CALDERON (CARAPUNGO)     I561002
# 1423447              QUITO                      QUITUMBE     G471101
#
#                                        ACTIVIDAD_ECONOMICA fecha_ano  \
# ID
# 0        INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2001
# 10       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2002
# 13       SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASI...      2001
# 15       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2001
# 18            EXTRACCIÓN DE CRETA Y DOLOMITA SIN CALCINAR.      2003
# 19       OTRAS ACTIVIDADES DE ASESORAMIENTO Y REPRESENT...      2001
# 21       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...      2002
# 22       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2007
# 23       OTROS SERVICIOS DE ALOJAMIENTOS POR CORTO TIEM...      2002
# 29       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2002
# 31       SERVICIOS DE ALOJAMIENTO PRESTADOS POR HOTELES...      2004
# 32       TRANSPORTE TERRESTRE DE PASAJEROS POR SISTEMAS...      1998
# 33       VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...      1999
# 34       FABRICACIÓN DE ESTATUILLAS Y ORNAMENTOS DE MAD...      2000
# 35       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...      2002
# 36       RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...      2003
# 37       VENTA AL POR MENOR DE PERFUMES, ARTÍCULOS COSM...      2000
# 40       SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASI...      1999
# 41       OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2000
# 42       SERVICIOS DE AUTOBUSES ESCOLARES Y AUTOBUSES P...      2000
# 52       ACTIVIDADES DE ATENCIÓN ODONTOLÓGICA DE CARÁCT...      2001
# 56       VENTA AL POR MENOR DE PERFUMES, ARTÍCULOS COSM...      2000
# 57       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...      2001
# 58       ACTIVIDADES LABORALES REALIZADAS BAJO RELACION...      2006
# 59       ACTIVIDADES DE ALQUILER DE AUTOMÓVILES PRIVADO...      2002
# 60                                     SERVICIOS DE TAXIS.      2001
# 61       ACTIVIDADES DE DISEÑO DE INGENIERÍA Y CONSULTO...      1999
# 62       ACTIVIDADES DE DISEÑO DE INGENIERÍA Y CONSULTO...      1999
# 65       VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...      2004
# 66       VENTA AL POR MENOR DE PRODUCTOS DE PANADERÍA, ...      2000
# ...                                                    ...       ...
# 1423262  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423263  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423264  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423265  VENTA AL POR MENOR DE BEBIDAS ALCOHÓLICAS (NO ...      2018
# 1423266  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423267  VENTA AL POR MAYOR DE BEBIDAS ALCOHÓLICAS, INC...      2018
# 1423268  VENTA AL POR MAYOR DE FRUTAS, LEGUMBRES Y HORT...      2018
# 1423269  ACTIVIDADES DE CONFECCIÓN A LA MEDIDA DE PREND...      2018
# 1423270  CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDEN...      2018
# 1423271  EXPLOTACIÓN DE CRIADEROS DE POLLOS Y REPRODUCC...      2018
# 1423272  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423273  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423293  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2016
# 1423296  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2015
# 1423297  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2018
# 1423304  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2017
# 1423307  ACTIVIDADES DE LAVADO, CORTE, RECORTE, PEINADO...      2018
# 1423326  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2018
# 1423327  INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...      2018
# 1423332  CONSULTA Y TRATAMIENTO POR MÉDICOS GENERALES Y...      2016
# 1423352  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2011
# 1423378  OTRAS ACTIVIDADES DE CONTABILIDAD, TENEDURÍA D...      2018
# 1423393  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2018
# 1423413  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...      2016
# 1423416  RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...      2018
# 1423417  RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...      2018
# 1423419  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...      2018
# 1423443  ACTIVIDADES DE CONFECCIÓN A LA MEDIDA DE PREND...      2006
# 1423445  RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...      2018
# 1423447  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...      2017
#
#         fecha_mes cantidad
# ID
# 0             Nov     4792
# 10            Feb     6608
# 13            Sep     1119
# 15            Apr     4173
# 18            Sep     4150
# 19            Sep      232
# 21            Apr     7305
# 22            Apr      375
# 23            Oct     2215
# 29            Jan     6703
# 31            Apr     1021
# 32            Apr      238
# 33            Jul     5360
# 34            Sep      531
# 35            Nov      203
# 36            Mar     4150
# 37            Jun     1796
# 40            Nov     5360
# 41            Nov     4890
# 42            Aug     3397
# 52            Aug     1304
# 56            Jun     4890
# 57            Feb     4173
# 58            Mar     3993
# 59            Nov     7305
# 60            Feb      301
# 61            Oct     1038
# 62            Oct     5360
# 65            Dec     4136
# 66            May     5273
# ...           ...      ...
# 1423262       Oct     6754
# 1423263       Oct     1240
# 1423264       Oct      773
# 1423265       May     1768
# 1423266       Oct      581
# 1423267       Oct     1004
# 1423268       Oct      354
# 1423269       Oct     1016
# 1423270       Oct     2196
# 1423271       Oct      292
# 1423272       Nov     4074
# 1423273       Dec     4074
# 1423293       Sep     1790
# 1423296       Dec     3601
# 1423297       Mar     1122
# 1423304       Oct     1853
# 1423307       Jan     4550
# 1423326       Apr     1104
# 1423327       Apr     1523
# 1423332       Jan      126
# 1423352       Jul     1130
# 1423378       Aug     1004
# 1423393       Oct     1889
# 1423413       May     3191
# 1423416       May      773
# 1423417       May      773
# 1423419       Nov     1124
# 1423443       Mar     4968
# 1423445       Jul     4074
# 1423447       May      945
#
# [1033788 rows x 25 columns]

# %% [markdown]
# ### Discretizando los datos - Nuevos contribuyentes
# Creamos una columna `PRESIDENTE` que determina el presidente durante el periodo de tiempo en que han registrado nuevos contribuyentes

# %%
mahuad_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(1998,8,10)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2000,1,22))].assign(PRESIDENTE='Jamil Mahuad')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
gn_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2000,1,22)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2003,1,5))].assign(PRESIDENTE='Gustavo Noboa')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
guti_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2003,1,5)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2005,4,20))].assign(PRESIDENTE='Lucio Gutiérrez')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
pala_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2005,4,20)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2007,1,15))].assign(PRESIDENTE='Alfredo Palacio')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc1_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2007,1,15)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2009,8,10))].assign(PRESIDENTE='Rafael Correa P1')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc2_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2009,8,10)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2013,5,24))].assign(PRESIDENTE='Rafael Correa P2')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc3_per_ini = df[(df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2013,5,24)) & (df['FECHA_INICIO_ACTIVIDADES'] < datetime.date(2017,5,24))].assign(PRESIDENTE='Rafael Correa P3')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_per_ini = df[df['FECHA_INICIO_ACTIVIDADES'] > datetime.date(2017,5,24)].assign(PRESIDENTE='Lenín Moreno')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_per_ini.head()
# Out:
#            NUMERO_RUC                         RAZON_SOCIAL  \
# ID
# 480552   100791011001         FAJARDO LOPEZ LAURO BENJAMIN
# 486829   102606928001       CALDERON COELLO JUANA CATALINA
# 504326   100976810001        SALCEDO CORDERO ELVIA CUMANDA
# 506347  1792729912001  EQUINOCCIO-CAPACITACIONES CIA.LTDA.
# 506348  1792729912001  EQUINOCCIO-CAPACITACIONES CIA.LTDA.
#
#                  NOMBRE_COMERCIAL ESTADO_CONTRIBUYENTE CLASE_CONTRIBUYENTE  \
# ID
# 480552                        NaN               ACTIVO                RISE
# 486829                        NaN               ACTIVO               OTROS
# 504326                        NaN               ACTIVO               OTROS
# 506347  EQUINOCCIO CAPACITACIONES               ACTIVO               OTROS
# 506348  EQUINOCCIO CAPACITACIONES               ACTIVO               OTROS
#
#        FECHA_INICIO_ACTIVIDADES FECHA_ACTUALIZACION  \
# ID
# 480552               2017-11-27          14/05/2018
# 486829               2018-09-07                 NaN
# 504326               2018-08-13                 NaN
# 506347               2017-12-01                 NaN
# 506348               2017-12-01                 NaN
#
#        FECHA_SUSPENSION_DEFINITIVA FECHA_REINICIO_ACTIVIDADES OBLIGADO  ...  \
# ID                                                                      ...
# 480552                         NaN                 14/05/2018        N  ...
# 486829                         NaN                        NaN        N  ...
# 504326                         NaN                        NaN        N  ...
# 506347                         NaN                        NaN        S  ...
# 506348                         NaN                        NaN        S  ...
#
#         NUMERO  INTERSECCION ESTADO_ESTABLECIMIENTO DESCRIPCION_PROVINCIA  \
# ID
# 480552      59           NaN                    ABI             PICHINCHA
# 486829     S/N  JAMES COLNET                    ABI             PICHINCHA
# 504326     O3E   ELOY ALFARO                    ABI             PICHINCHA
# 506347  N57-77           S/N                    ABI             PICHINCHA
# 506348  N57-77           S/N                    ABI             PICHINCHA
#
#        DESCRIPCION_CANTON         DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 480552              QUITO                      AMAGUAÑA     G466922
# 486829              QUITO                     RUMIPAMBA     P853002
# 504326              QUITO                      JIPIJAPA     G477111
# 506347              QUITO  QUITO DISTRITO METROPOLITANO     P854911
# 506348              QUITO  QUITO DISTRITO METROPOLITANO     P854911
#
#                                       ACTIVIDAD_ECONOMICA fecha_ano  \
# ID
# 480552             VENTA AL POR MAYOR DEL PAPEL Y CARTÓN.      2017
# 486829  EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...      2018
# 504326  VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...      2018
# 506347  ACTIVIDADES DE ENSEÑANZA QUE NO PUEDE ASIGNARS...      2017
# 506348  ACTIVIDADES DE ENSEÑANZA QUE NO PUEDE ASIGNARS...      2017
#
#           PRESIDENTE
# ID
# 480552  Lenín Moreno
# 486829  Lenín Moreno
# 504326  Lenín Moreno
# 506347  Lenín Moreno
# 506348  Lenín Moreno
#
# [5 rows x 24 columns]

# %%
cdf = pd.concat([mahuad_per_ini, gn_per_ini, guti_per_ini, pala_per_ini, rc1_per_ini, rc2_per_ini, rc3_per_ini, lenin_per_ini])

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='PRESIDENTE', data=cdf,color=COLOR)
ax.set(ylabel='PROMEDIO DE NUEVOS CONTRIBUYENTES POR DÍA',xlabel="PERIODOS PRESIDENCIALES", title='Promedio por día de nuevos contribuyentes deacuerdo al periodo presidencial',ylim=(0, 165))
total = float(len(cdf))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
uso_nuevos = dias_x_periodo.copy()
for p in ax.patches:
    dias = uso_nuevos.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %%
plt.figure(figsize=(16, 6))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498,780,1461,1322,969,635,826,1089,498,780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
uso_nuevos = dias_x_periodo.copy()
ax = sns.countplot(x='PRESIDENTE', data=cdf, hue="ESTADO_CONTRIBUYENTE",palette=sns.color_palette("Set1", n_colors=3, desat=.5))
ax.set(ylabel='PROMEDIO DE NUEVOS CONTRIBUYENTES POR DÍA',xlabel="PERIODOS PRESIDENCIALES", title='Promedio por día de nuevos contribuyentes por periodos presidenciales categorizados por el estado actual del contribuyente',ylim=(0, 105))
total = float(len(cdf))
for p in ax.patches:
    dias = uso_nuevos.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %%
df2 = guayaquil.dropna(subset=['FECHA_SUSPENSION_DEFINITIVA'])

# %%
df2
# Out:
#             NUMERO_RUC                                       RAZON_SOCIAL  \
# ID
# 1         100081728001                        QUITO TENEMASA LUIS ANTONIO
# 2         100086859001                      LLIVISACA NAUTA MARIA ROSARIO
# 3         100123975001                     RODAS MORALES RAQUEL DEL PILAR
# 10        100149590001                    ORDONEZ ORDONEZ SERGIO CLOTARIO
# 11        100207596001                         SIGSI MARQUEZ JUAN RODRIGO
# 12        100267400001                     ENCALADA ESPINOZA RAQUEL MARIA
# 14        100347616001                       ZHUNIO AUQUILLA ANGEL SEVERO
# 16        100523612001                              VERA VERA ROSA ELVIRA
# 17        100416478001                      LOPEZ HERMIDA JULIA CARMELINA
# 18        100011113001                     CEVALLOS FAJARDO LIGIA BRIGIDA
# 19        100021120001                                 PEÑA UGALDE GENARO
# 20        100074640001                      ORDONEZ GUARDERAS EDY ALMAGRO
# 21        100040088001                     GRANDA UGALDE EDMUNDO HUMBERTO
# 22        100040146001  JERVES VAZQUEZ AUGUSTO NICOLAS RICARDO PORFIRIO M
# 23        100133388001                          REYES CADENA FANNY ALICIA
# 29        100081702001                        ELJURI CORDERO GABRIEL JOSE
# 33        100143338001                      PERALTA BACUILIMA MANUEL CRUZ
# 35        100178201001                    ALVAREZ PACHECO CLAUDIO EUGENIO
# 36        100194364001                         DELEG DUQUE MIGUEL ANTONIO
# 37        100209170001                     GALAN PRIETO MARIANA ORFELINDA
# 38        100246495001                          VELASTEGUI BLANCA ESTHELA
# 39        100273796001                     ZHAGUI CHUCHUCA MANUEL GERARDO
# 40        100300516001                        PINEDA OROSCO COLON ENRIQUE
# 41        100342088001                          SAA UTRERAS MARIA MARIANA
# 42        100331958001                          JIMA VEGA JOSE FLORENTINO
# 50        100340140001                             NARANJO CURICHO MANUEL
# 51        100340140001                             NARANJO CURICHO MANUEL
# 52        100060334001                       GUERRERO VARGAS EDGAR HERNAN
# 57        100043223001                          MORAN ERAZO LUIS HUMBERTO
# 58        100035427001                  VANEGAS CORONEL BENJAMIN HERMINIO
# ...                ...                                                ...
# 1422598  1724591217001                CALUGUILLIN CUASCOTA ANGELICA ROCIO
# 1422615  1707906572001            JACOME CABEZAS CARMEN GIOVANNA PATRICIA
# 1422616  1707906572001            JACOME CABEZAS CARMEN GIOVANNA PATRICIA
# 1422627  1723040760001                MACHADO CHAGÑAY CAROLINA MONSERRATH
# 1422639  1723955637001                          CORAL ALAVA ESTEBAN DAVID
# 1422687  1792893658001                    RODRIGUEZ ESPAÑA HEIRY VICTORIA
# 1422725  3050611726001                       GARCIA ARCHILE EDUARDO DAVID
# 1422751   803490341001                   CASTILLO BUESTAN TANIA ELIZABETH
# 1422755  1758619975001               PARRA VILLALOBOS ELAINE CHIQUINQUIRA
# 1422776  1723350797001                      SINGO GANAZHAPA JOSE SANTIAGO
# 1422797  1723655740001            GUACHICHULCA GALLEGOS KATHERINE VANESSA
# 1422803  1723962104001                        CHANGO CAIZA JESSICA JANETH
# 1422806  1724176662001                        SANTILLAN MORALES ANA LUCIA
# 1422807  1724288996001                     NAULA QUINATOA JESSICA NATHALY
# 1422808  1724309289001                           CORO MAILA DAVID ALFREDO
# 1422842  1711975647001                             MENESES GANDARA JAVIER
# 1422957  1718848664001                     AGUAYO ARGUELLO CHRISTIAN RENE
# 1422979   401042700001                    ANDRADE CUASAPAZ OLGA GUADALUPE
# 1422980   401151030001                 HUERA VILLARREAL SEGUNDO SIGIFREDO
# 1422981  1314121532001                        MOREIRA PARRAGA LUIS MIGUEL
# 1423074  1754057824001                     MARTINEZ GONZALES BRILLY NEVEL
# 1423089  1717888810001                                         MAI XIKANG
# 1423090  1717888810001                                         MAI XIKANG
# 1423177  1725149627001                       PEREZ MARQUEZ MARITZA XIMENA
# 1423188   604076810001                     LARREA GONZALEZ MARIA GABRIELA
# 1423206  1792955661001                     MORALES GUERRERO ALVARO JUNIOR
# 1423293  1309344222001                        CELI ABEIGA RICARDO ALFONSO
# 1423443   502264088001                    PAZMIÑO CASTELLANO MARIA ISABEL
# 1423445   502913015001                       CHICAIZA TONATO NORMA XIMENA
# 1423447  1203358286001                 GARCIA CRUZ MARTIRE DE LOS ANGELES
#
#                                         NOMBRE_COMERCIAL ESTADO_CONTRIBUYENTE  \
# ID
# 1                                VULCANIZADORA MAGDALENA           SUSPENDIDO
# 2                                                    NaN           SUSPENDIDO
# 3                                                    NaN               ACTIVO
# 10                                                   NaN               ACTIVO
# 11                                                   NaN           SUSPENDIDO
# 12                                      LA NUEVA JOYERIA           SUSPENDIDO
# 14                                                   NaN           SUSPENDIDO
# 16                                        VIVERES IBERIA           SUSPENDIDO
# 17                                    RESTAURANTE FORTIN           SUSPENDIDO
# 18                                                   NaN           SUSPENDIDO
# 19                                                   NaN           SUSPENDIDO
# 20       COOPERATIVA DE TAXIS 6 DE MARZO RUMINAHUI NO 88               PASIVO
# 21                                                   NaN           SUSPENDIDO
# 22                                                   NaN               PASIVO
# 23                                                   NaN           SUSPENDIDO
# 29                                                   NaN           SUSPENDIDO
# 33                                       VIVERES PABLITO           SUSPENDIDO
# 35                                                   NaN           SUSPENDIDO
# 36                                                   NaN           SUSPENDIDO
# 37                                               MARISOL           SUSPENDIDO
# 38                                                   NaN           SUSPENDIDO
# 39                                                   NaN           SUSPENDIDO
# 40                                          COLON PINEDA           SUSPENDIDO
# 41                                                   NaN           SUSPENDIDO
# 42                                                   NaN               ACTIVO
# 50                                             HNS HANAM               PASIVO
# 51                                             HNS HANAM               PASIVO
# 52                                                   NaN           SUSPENDIDO
# 57                                                   NaN               PASIVO
# 58                                                   NaN           SUSPENDIDO
# ...                                                  ...                  ...
# 1422598                                              NaN           SUSPENDIDO
# 1422615                                              NaN           SUSPENDIDO
# 1422616                                              NaN           SUSPENDIDO
# 1422627                                              NaN           SUSPENDIDO
# 1422639                                              NaN           SUSPENDIDO
# 1422687                                              NaN               PASIVO
# 1422725                                              NaN           SUSPENDIDO
# 1422751                                              NaN           SUSPENDIDO
# 1422755                                              NaN           SUSPENDIDO
# 1422776                                              NaN           SUSPENDIDO
# 1422797                                              NaN           SUSPENDIDO
# 1422803                                              NaN           SUSPENDIDO
# 1422806                                              NaN           SUSPENDIDO
# 1422807                                              NaN           SUSPENDIDO
# 1422808                                              NaN           SUSPENDIDO
# 1422842                                              NaN           SUSPENDIDO
# 1422957                                              NaN           SUSPENDIDO
# 1422979                                              NaN           SUSPENDIDO
# 1422980                                              NaN           SUSPENDIDO
# 1422981                                              NaN           SUSPENDIDO
# 1423074                                              NaN           SUSPENDIDO
# 1423089                                              NaN               ACTIVO
# 1423090                                              NaN               ACTIVO
# 1423177                                              NaN           SUSPENDIDO
# 1423188                                              NaN           SUSPENDIDO
# 1423206                                              NaN               PASIVO
# 1423293                                              NaN           SUSPENDIDO
# 1423443                      SASTRERIA Y MODAS ISABELITA           SUSPENDIDO
# 1423445                                              NaN           SUSPENDIDO
# 1423447                                              NaN           SUSPENDIDO
#
#         CLASE_CONTRIBUYENTE FECHA_INICIO_ACTIVIDADES FECHA_ACTUALIZACION  \
# ID
# 1                     OTROS               18/05/1973          17/04/2001
# 2                     OTROS               17/10/1996          09/04/2002
# 3                     OTROS               12/10/1992          14/07/2015
# 10                    OTROS               14/02/2002          16/11/2009
# 11                    OTROS               03/10/1997          25/03/2002
# 12                    OTROS               10/04/1973          18/10/1994
# 14                    OTROS               12/05/1997                 NaN
# 16                    OTROS               29/08/1975          01/08/2002
# 17                    OTROS               01/12/1977          11/06/1996
# 18                    OTROS               24/09/2003          24/09/2003
# 19                    OTROS               13/09/2001          02/08/2017
# 20                    OTROS               26/02/1997          04/02/2003
# 21                    OTROS               29/04/2002                 NaN
# 22                    OTROS               19/04/2007          01/09/2010
# 23                    OTROS               14/10/2002                 NaN
# 29                    OTROS               29/01/2002          23/05/2017
# 33                    OTROS               07/06/1999          15/02/2001
# 35                    OTROS               18/11/2002          18/01/2013
# 36                    OTROS               19/03/2003          28/03/2003
# 37                    OTROS               06/10/2000                 NaN
# 38                    OTROS               01/12/1991          26/07/2012
# 39                    OTROS               06/05/1997          08/10/2014
# 40                    OTROS               16/11/1999          16/11/1999
# 41                    OTROS               17/11/2000                 NaN
# 42                    OTROS               08/03/2000          30/07/2018
# 50                    OTROS               25/02/1980          24/11/2000
# 51                    OTROS               25/02/1980          24/11/2000
# 52                    OTROS               08/05/2001          26/07/2002
# 57                    OTROS               02/05/2001          27/07/2009
# 58                    OTROS               28/03/2006          01/07/2011
# ...                     ...                      ...                 ...
# 1422598               OTROS               05/10/2017                 NaN
# 1422615               OTROS               16/01/1990          24/01/2019
# 1422616               OTROS               16/01/1990          24/01/2019
# 1422627               OTROS               10/01/2019                 NaN
# 1422639               OTROS               10/01/2019                 NaN
# 1422687               OTROS               09/08/2018                 NaN
# 1422725               OTROS               25/09/2018                 NaN
# 1422751               OTROS               05/07/2018                 NaN
# 1422755               OTROS               11/06/2018                 NaN
# 1422776               OTROS               29/01/2019                 NaN
# 1422797               OTROS               02/05/2018                 NaN
# 1422803               OTROS               04/05/2018                 NaN
# 1422806               OTROS               10/12/2018                 NaN
# 1422807               OTROS               10/12/2018                 NaN
# 1422808               OTROS               28/05/2018                 NaN
# 1422842               OTROS               04/09/2018                 NaN
# 1422957               OTROS               27/09/2017                 NaN
# 1422979               OTROS               30/07/2018                 NaN
# 1422980               OTROS               12/03/2007          31/07/2017
# 1422981               OTROS               02/07/2018          02/07/2018
# 1423074               OTROS               12/06/2018                 NaN
# 1423089               OTROS               09/01/2003          01/02/2019
# 1423090               OTROS               09/01/2003          01/02/2019
# 1423177               OTROS               03/01/2019                 NaN
# 1423188               OTROS               29/01/2019                 NaN
# 1423206               OTROS               04/02/2019                 NaN
# 1423293               OTROS               13/09/2016                 NaN
# 1423443               OTROS               27/03/2006          16/10/2017
# 1423445               OTROS               27/07/2018                 NaN
# 1423447               OTROS               29/05/2017                 NaN
#
#         FECHA_SUSPENSION_DEFINITIVA FECHA_REINICIO_ACTIVIDADES OBLIGADO  ...  \
# ID                                                                       ...
# 1                        13/09/2006                        NaN        N  ...
# 2                        31/12/2001                        NaN        N  ...
# 3                        16/01/2002                 16/05/2003        N  ...
# 10                       11/08/2003                 11/08/2003        N  ...
# 11                       13/07/2010                        NaN        N  ...
# 12                       11/11/2008                        NaN        N  ...
# 14                       13/09/2006                        NaN        N  ...
# 16                       30/04/2002                        NaN        N  ...
# 17                       28/02/1996                        NaN        N  ...
# 18                       20/08/2004                        NaN        N  ...
# 19                       15/08/2017                 02/08/2017        N  ...
# 20                       30/10/1998                 08/06/1999        N  ...
# 21                       13/09/2006                        NaN        N  ...
# 22                       25/08/2011                        NaN        N  ...
# 23                       18/05/2009                        NaN        N  ...
# 29                       27/07/2018                 23/05/2017        N  ...
# 33                       30/11/2000                        NaN        N  ...
# 35                       13/06/2013                        NaN        N  ...
# 36                       31/08/2011                        NaN        N  ...
# 37                       13/09/2006                        NaN        N  ...
# 38                       30/01/2013                 26/07/2012        N  ...
# 39                       06/03/2017                 05/05/2014        N  ...
# 40                       31/08/2011                        NaN        N  ...
# 41                       13/09/2006                        NaN        N  ...
# 42                       08/01/2004                 07/06/2004        N  ...
# 50                       29/09/2009                        NaN        N  ...
# 51                       29/09/2009                        NaN        N  ...
# 52                       10/01/2014                        NaN        N  ...
# 57                       28/12/2010                        NaN        N  ...
# 58                       11/05/2016                        NaN        N  ...
# ...                             ...                        ...      ...  ...
# 1422598                  12/12/2018                        NaN        N  ...
# 1422615                  28/01/2019                 24/01/2019        N  ...
# 1422616                  28/01/2019                 24/01/2019        N  ...
# 1422627                  06/02/2019                        NaN        N  ...
# 1422639                  07/02/2019                        NaN        N  ...
# 1422687                  29/01/2019                        NaN        N  ...
# 1422725                  18/01/2019                        NaN        N  ...
# 1422751                  07/02/2019                        NaN        N  ...
# 1422755                  07/02/2019                        NaN        N  ...
# 1422776                  08/02/2019                        NaN        N  ...
# 1422797                  10/12/2018                        NaN        N  ...
# 1422803                  10/12/2018                        NaN        N  ...
# 1422806                  26/12/2018                        NaN        N  ...
# 1422807                  26/12/2018                        NaN        N  ...
# 1422808                  27/12/2018                        NaN        N  ...
# 1422842                  04/09/2018                        NaN        N  ...
# 1422957                  21/01/2019                        NaN        N  ...
# 1422979                  07/02/2019                        NaN        N  ...
# 1422980                  07/02/2019                 31/07/2017        N  ...
# 1422981                  07/02/2019                        NaN        N  ...
# 1423074                  09/01/2019                        NaN        N  ...
# 1423089                  29/01/2010                 25/01/2019        N  ...
# 1423090                  29/01/2010                 25/01/2019        N  ...
# 1423177                  07/02/2019                        NaN        N  ...
# 1423188                  06/02/2019                        NaN        N  ...
# 1423206                  07/02/2019                        NaN        N  ...
# 1423293                  25/01/2019                        NaN        N  ...
# 1423443                  08/02/2019                 16/10/2017        N  ...
# 1423445                  08/02/2019                        NaN        N  ...
# 1423447                  07/02/2019                        NaN        N  ...
#
#                                NOMBRE_FANTASIA_COMERCIAL  \
# ID
# 1                                VULCANIZADORA MAGDALENA
# 2                                                    NaN
# 3                                                    NaN
# 10                                                   NaN
# 11                       EN LA COOP DE TAXIS SAN BLAS #6
# 12                                      LA NUEVA JOYERIA
# 14                                                   NaN
# 16                                        VIVERES IBERIA
# 17                                    RESTAURANTE FORTIN
# 18                                                   NaN
# 19                                                   NaN
# 20       COOPERATIVA DE TAXIS 6 DE MARZO RUMINAHUI NO 88
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 29                                                   NaN
# 33                                       VIVERES PABLITO
# 35                                                   NaN
# 36                                                   NaN
# 37                                               MARISOL
# 38                                      SALON 24 DE MAYO
# 39                                                   NaN
# 40                                          COLON PINEDA
# 41                                                   NaN
# 42                                                   NaN
# 50                                NARANJO CURICHO MANUEL
# 51                                            HNS  HANAM
# 52                                                   NaN
# 57                                                   NaN
# 58                                                   NaN
# ...                                                  ...
# 1422598                                              NaN
# 1422615                                              NaN
# 1422616                                           GIOVAS
# 1422627                                              NaN
# 1422639                                              NaN
# 1422687                                              NaN
# 1422725                                              NaN
# 1422751                                  LA SAZON DEL 14
# 1422755                                              NaN
# 1422776                                              NaN
# 1422797                                              NaN
# 1422803                                              NaN
# 1422806                    BAR KARAOKE DIOSES DEL OLIMPO
# 1422807                                              NaN
# 1422808                                              NaN
# 1422842                                              NaN
# 1422957                                              NaN
# 1422979                                              NaN
# 1422980                                              NaN
# 1422981                                              NaN
# 1423074                                              NaN
# 1423089                                       EL CHINITO
# 1423090                                       EL CHINITO
# 1423177                                              NaN
# 1423188                                              NaN
# 1423206                                              NaN
# 1423293                                              NaN
# 1423443                                              NaN
# 1423445                                              NaN
# 1423447                                      VIVERES H.G
#
#                                   CALLE   NUMERO               INTERSECCION  \
# ID
# 1                               CANARIS      424                  DUCHICELA
# 2                             RIO NUEVO      S/N                  PORTOVELO
# 3                   ANTONIO DE MARCHENA   OE1-71           AV. 10 DE AGOSTO
# 10             CRISTOBAL VACA DE CASTRO  OE5-233                    MACHALA
# 11                PEDRO FERMIN CEVALLOS       SN                   ANTEPARA
# 12                              BOLIVAR      420              GARCIA MORENO
# 14       OLAN SOLANDA SUPER MZ 2 PASAJE      S/N                        NaN
# 16                         RAFAEL TROYA      336              PADRE ALMEIDA
# 17                                MEJIA      650                     CUENCA
# 18                       MANUEL AMBROSI      S-N        AVENIDA ELOY ALFARO
# 19                            PRINCIPAL      S/N                 SECUNDARIA
# 20                          DIEGO BARBA      238              LUIS ARGADONA
# 21                      SANTIAGO DUARTE   OE3-37                     BRASIL
# 22                       RIO CORRIENTES       68                RIO CURARAY
# 23                            GROSELLAS     LT 6                        NaN
# 29                   AV. 6 DE DICIEMBRE     4122                   EL BATAN
# 33                   CONZALO ZALDUMBIDE   N51-26                 BUSTAMANTE
# 35                             PASAJE 4  LOTE 46             VIA AL QUINCHE
# 36                            LAS VIÑAS  E13-121             LOS GUAYACANES
# 37                       VIA MARIANITAS       SN                        NaN
# 38                        S12B/CHANCHAN   E6-137        E7/NARIZ DEL DIABLO
# 39                                    9  OE12-40               JORGE PIEDRA
# 40                         LAS AZUCENAS     43-A                 LAS MALVAS
# 41                      NASACOTA PUENTO      S/N                PEDRO BOTTO
# 42                       ESTEBAN ALONSO  S32-298                        NaN
# 50                       VICTOR MIDEROS      576                        NaN
# 51                         10 DE AGOSTO   14-107                   RIO FRIO
# 52                     ANTONIO DE PRADO    E2-26           AV. ISIDRO AYORA
# 57                       HERNAN  CORTEZ   N58-74                 ANDAGUIRRE
# 58                       CARLOS DOSSMAN   N59-38               ANGEL LUDEÑA
# ...                                 ...      ...                        ...
# 1422598                    AV. JAZMINES   N55-52                LOS FRESNOS
# 1422615                AV. DE LA PRENSA      S/N           PASAJE ITURRALDE
# 1422616                   CAPITAN RAMOS   N10-90          AV DIEZ DE AGOSTO
# 1422627             E19F RICHARD BURGOS   S4-115           S4C HECTOR CHICA
# 1422639                      LOS CACTUS       33                 LOS CEDROS
# 1422687                    JUAN ACEVEDO       C8           ALCOCER HERNANDO
# 1422725                       TANICUCHI   S14-30         JOAQUIN GUITIERREZ
# 1422751                      LA DELICIA  OE10-15                      OE10A
# 1422755            E7C M. G. D LA TORRE   S25-42                       S26C
# 1422776                EMILIO JARAMILLO  N57-154              ZULEMA BLACIO
# 1422797                            OE9A  S26-112                 CALLE S26C
# 1422803                        IMBABURA    N1-75                  SAN ROQUE
# 1422806                        PASAJE E       E1                          A
# 1422807                            S51C      139                        E6C
# 1422808                             S6C  LOTE 48                   PASAJE 2
# 1422842                             NaN      NaN                        NaN
# 1422957                   AV. MALDONADO    E1-42                   BEATERIO
# 1422979                    LINEA FERREA       SN            PSJE SANTA ROSA
# 1422980                               D     1247                        NaN
# 1422981                 CESAR VILLACRES   OE9-18         AV. MARISCAL SUCRE
# 1423074                PASAJE CASPICARA       SN                  CARAPUNGO
# 1423089                           CHILE   OE6-58  ENTRE BENALCAZAR Y CUENCA
# 1423090                           CHILE    OE836                   MONTUFAR
# 1423177                            OE7E   S13-89                        S13
# 1423188          N42 MARIANO ECHEVERIIA   OE2-41                   VOZANDES
# 1423206                          GERONA      866                    VIZCAYA
# 1423293                        AVIGIRAS   LT 130                 GUAYACANES
# 1423443                             S43  LOTE 14               PASAJE OE9-H
# 1423445                  LOS PICAFLORES  LOTE 60               LAS CIGUEÑAS
# 1423447                            S43B    CS-27          OE4 RUMICHACA ÑAN
#
#         ESTADO_ESTABLECIMIENTO DESCRIPCION_PROVINCIA DESCRIPCION_CANTON  \
# ID
# 1                          CER             PICHINCHA              QUITO
# 2                          CER             PICHINCHA              QUITO
# 3                          ABI             PICHINCHA              QUITO
# 10                         ABI             PICHINCHA              QUITO
# 11                         CER             PICHINCHA              QUITO
# 12                         CER             PICHINCHA              QUITO
# 14                         CER             PICHINCHA              QUITO
# 16                         CER             PICHINCHA              QUITO
# 17                         CER             PICHINCHA              QUITO
# 18                         CER             PICHINCHA              QUITO
# 19                         CER             PICHINCHA              QUITO
# 20                         CER             PICHINCHA              QUITO
# 21                         CER             PICHINCHA              QUITO
# 22                         CER             PICHINCHA              QUITO
# 23                         CER             PICHINCHA              QUITO
# 29                         CER             PICHINCHA              QUITO
# 33                         CER             PICHINCHA              QUITO
# 35                         CER             PICHINCHA              QUITO
# 36                         CER             PICHINCHA              QUITO
# 37                         CER             PICHINCHA              QUITO
# 38                         CER             PICHINCHA              QUITO
# 39                         CER             PICHINCHA              QUITO
# 40                         CER             PICHINCHA              QUITO
# 41                         CER             PICHINCHA              QUITO
# 42                         ABI             PICHINCHA              QUITO
# 50                         CER             PICHINCHA              QUITO
# 51                         CER             PICHINCHA              QUITO
# 52                         CER             PICHINCHA              QUITO
# 57                         CER             PICHINCHA              QUITO
# 58                         CER             PICHINCHA              QUITO
# ...                        ...                   ...                ...
# 1422598                    CER             PICHINCHA              QUITO
# 1422615                    CER             PICHINCHA              QUITO
# 1422616                    CER             PICHINCHA              QUITO
# 1422627                    CER             PICHINCHA              QUITO
# 1422639                    CER             PICHINCHA              QUITO
# 1422687                    CER             PICHINCHA              QUITO
# 1422725                    CER             PICHINCHA              QUITO
# 1422751                    CER             PICHINCHA              QUITO
# 1422755                    CER             PICHINCHA              QUITO
# 1422776                    CER             PICHINCHA              QUITO
# 1422797                    CER             PICHINCHA              QUITO
# 1422803                    CER             PICHINCHA              QUITO
# 1422806                    CER             PICHINCHA              QUITO
# 1422807                    CER             PICHINCHA              QUITO
# 1422808                    CER             PICHINCHA              QUITO
# 1422842                    CER             PICHINCHA              QUITO
# 1422957                    CER             PICHINCHA              QUITO
# 1422979                    CER             PICHINCHA              QUITO
# 1422980                    CER             PICHINCHA              QUITO
# 1422981                    CER             PICHINCHA              QUITO
# 1423074                    CER             PICHINCHA              QUITO
# 1423089                    ABI             PICHINCHA              QUITO
# 1423090                    CER             PICHINCHA              QUITO
# 1423177                    CER             PICHINCHA              QUITO
# 1423188                    CER             PICHINCHA              QUITO
# 1423206                    CER             PICHINCHA              QUITO
# 1423293                    CER             PICHINCHA              QUITO
# 1423443                    CER             PICHINCHA              QUITO
# 1423445                    CER             PICHINCHA              QUITO
# 1423447                    CER             PICHINCHA              QUITO
#
#         DESCRIPCION_PARROQUIA CODIGO_CIIU  \
# ID
# 1                LA MAGDALENA     G452001
# 2                 CHILLOGALLO     I563002
# 3                    SAN JUAN     P854994
# 10                 COTOCOLLAO     L682002
# 11           CENTRO HISTÓRICO     H492202
# 12           CENTRO HISTÓRICO     S952301
# 14                CHILLOGALLO     G463011
# 16           CENTRO HISTÓRICO     G471101
# 17           CENTRO HISTÓRICO     I561001
# 18                 COTOCOLLAO     B081014
# 19                      NAYON     M691009
# 20                CHILLOGALLO     H492202
# 21              LA CONCEPCIÓN     P853002
# 22                   ALANGASI     L682002
# 23                    KENNEDY     I551009
# 29                   IÑAQUITO     L682002
# 33              LA CONCEPCIÓN     G471101
# 35               GUAYLLABAMBA     P853002
# 36                 COTOCOLLAO     I561002
# 37       CALDERON (CARAPUNGO)     G477205
# 38               LA MAGDALENA     I563002
# 39              LA CONCEPCIÓN     C239101
# 40              LA CONCEPCIÓN     M702003
# 41                 COTOCOLLAO     M749010
# 42                CHILLOGALLO     H492205
# 50              LA CONCEPCIÓN     G477201
# 51                   SAN JUAN     G477201
# 52                   CARCELÉN     Q862002
# 57                 COTOCOLLAO     P853002
# 58                 COTOCOLLAO     W200000
# ...                       ...         ...
# 1422598         LA CONCEPCIÓN     S960907
# 1422615         LA CONCEPCIÓN     G471900
# 1422616               KENNEDY     G471900
# 1422627           CHIMBACALLE     M749010
# 1422639        MARISCAL SUCRE     M749010
# 1422687     BELISARIO QUEVEDO     Q862002
# 1422725        LA FERROVIARIA     S960907
# 1422751        LA ECUATORIANA     I561001
# 1422755            LA ARGELIA     G472105
# 1422776            COCHAPAMBA     G479902
# 1422797               LA MENA     G477111
# 1422803      CENTRO HISTÓRICO     S960200
# 1422806        LA FERROVIARIA     R932903
# 1422807             TURUBAMBA     G479902
# 1422808              PUENGASÍ     I561002
# 1422842         LA CONCEPCIÓN     V030000
# 1422957           CHILLOGALLO     F410020
# 1422979               YARUQUI     S960907
# 1422980         LA CONCEPCIÓN     A014102
# 1422981         LA CONCEPCIÓN     G476101
# 1423074  CALDERON (CARAPUNGO)     G463033
# 1423089              CARCELÉN     G463033
# 1423090              CARCELÉN     G463033
# 1423177             CHILIBULO     G479902
# 1423188         LA CONCEPCIÓN     S960907
# 1423206             ITCHIMBIA     S960907
# 1423293               KENNEDY     M749010
# 1423443          LA MAGDALENA     C141004
# 1423445  CALDERON (CARAPUNGO)     I561002
# 1423447              QUITUMBE     G471101
#
#                                        ACTIVIDAD_ECONOMICA
# ID
# 1        MANTENIMIENTO Y REPARACIÓN DE VEHÍCULOS AUTOMO...
# 2        ACTIVIDADES DE PREPARACIÓN Y SERVICIO DE BEBID...
# 3                          OTROS TIPOS DE ENSEÑANZA N.C.P.
# 10       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 11                                     SERVICIOS DE TAXIS.
# 12       REPARACIÓN Y MANTENIMIENTO DE CALZADO: ZAPATOS...
# 14                 VENTA AL POR MAYOR DE BANANO Y PLÁTANO.
# 16       VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 17       RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...
# 18            EXTRACCIÓN DE CRETA Y DOLOMITA SIN CALCINAR.
# 19       OTRAS ACTIVIDADES DE ASESORAMIENTO Y REPRESENT...
# 20                                     SERVICIOS DE TAXIS.
# 21       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...
# 22       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 23       OTROS SERVICIOS DE ALOJAMIENTOS POR CORTO TIEM...
# 29       INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 33       VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 35       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...
# 36       RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...
# 37       VENTA AL POR MENOR DE PERFUMES, ARTÍCULOS COSM...
# 38       ACTIVIDADES DE PREPARACIÓN Y SERVICIO DE BEBID...
# 39       FABRICACIÓN DE ARTÍCULOS PARA CONSTRUCCIÓN: LO...
# 40       SERVICIOS DE  ASESORAMIENTO, ORIENTACIÓN Y ASI...
# 41       OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 42       SERVICIOS DE AUTOBUSES ESCOLARES Y AUTOBUSES P...
# 50       VENTA AL POR MENOR DE PRODUCTOS FARMACÉUTICOS ...
# 51       VENTA AL POR MENOR DE PRODUCTOS FARMACÉUTICOS ...
# 52       ACTIVIDADES DE ATENCIÓN ODONTOLÓGICA DE CARÁCT...
# 57       EDUCACIÓN DE TERCER NIVEL, DESTINADO A LA FORM...
# 58       ACTIVIDADES LABORALES REALIZADAS BAJO RELACION...
# ...                                                    ...
# 1422598  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1422615  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 1422616  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 1422627  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 1422639  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 1422687  ACTIVIDADES DE ATENCIÓN ODONTOLÓGICA DE CARÁCT...
# 1422725  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1422751  RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...
# 1422755  VENTA AL POR MENOR DE PRODUCTOS DE PANADERÍA, ...
# 1422776  VENTA AL POR MENOR POR COMISIONISTAS (NO DEPEN...
# 1422797  VENTA AL POR MENOR DE PRENDAS DE VESTIR Y PELE...
# 1422803  ACTIVIDADES DE LAVADO, CORTE, RECORTE, PEINADO...
# 1422806  ACTIVIDADES DE EXPLOTACIÓN DE DISCOTECAS Y PIS...
# 1422807  VENTA AL POR MENOR POR COMISIONISTAS (NO DEPEN...
# 1422808  RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...
# 1422842                     SIN ACTIVIDAD ECONOMICA - CIIU
# 1422957  CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS NO RESI...
# 1422979  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1422980                 PRODUCCIÓN DE LECHE CRUDA DE VACA.
# 1422981  VENTA AL POR MENOR DE LIBROS DE TODO TIPO EN E...
# 1423074  VENTA AL POR MAYOR DE PESCADO, CRUSTÁCEOS, MOL...
# 1423089  VENTA AL POR MAYOR DE PESCADO, CRUSTÁCEOS, MOL...
# 1423090  VENTA AL POR MAYOR DE PESCADO, CRUSTÁCEOS, MOL...
# 1423177  VENTA AL POR MENOR POR COMISIONISTAS (NO DEPEN...
# 1423188  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1423206  ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1423293  OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 1423443  ACTIVIDADES DE CONFECCIÓN A LA MEDIDA DE PREND...
# 1423445  RESTAURANTES DE COMIDA RÁPIDA, PUESTOS DE REFR...
# 1423447  VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
#
# [684302 rows x 22 columns]

# %%
df2['FECHA_SUSPENSION_DEFINITIVA'] = pd.to_datetime(df2['FECHA_SUSPENSION_DEFINITIVA'])
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mahuad_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(1998,8,10)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2000,1,22))].assign(PRESIDENTE='Jamil Mahuad')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
gn_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2000,1,22)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2003,1,5))].assign(PRESIDENTE='Gustavo Noboa')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
guti_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2003,1,5)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2005,4,20))].assign(PRESIDENTE='Lucio Gutiérrez')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
pala_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2005,4,20)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2007,1,15))].assign(PRESIDENTE='Alfredo Palacio')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc1_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2007,1,15)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2009,8,10))].assign(PRESIDENTE='Rafael Correa P1')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc2_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2009,8,10)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2013,5,24))].assign(PRESIDENTE='Rafael Correa P2')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
rc3_susp = df2[(df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2013,5,24)) & (df2['FECHA_SUSPENSION_DEFINITIVA'] < datetime.date(2017,5,24))].assign(PRESIDENTE='Rafael Correa P3')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
lenin_susp = df2[df2['FECHA_SUSPENSION_DEFINITIVA'] > datetime.date(2017,5,24)].assign(PRESIDENTE='Lenín Moreno')
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.

# %%
cdf2 = pd.concat([mahuad_susp,gn_susp, guti_susp, pala_susp, rc1_susp, rc2_susp, rc3_susp, lenin_susp])

# %%
plt.figure(figsize=(16, 6))
dias_x_periodo = [780,1461,1322,969,635,826,1089,498]  # jm - lenin  --
ax = sns.countplot(x='PRESIDENTE', data=cdf2,color=COLOR)
ax.set(ylabel='PROMEDIO CONTRIBUYENTES SUSPENDIDOS POR DÍA', xlabel="PERIODOS PRESIDENCIALES",title='Promedio por día de contribuyentes suspendidos deacuerdo al periodo presidencial',ylim=(0, 270))
total = float(len(cdf))
for p in ax.patches:
    dias = dias_x_periodo.pop()
    p.set_height(p.get_height()/dias)
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.0f}'.format(height),
            ha="center")

# %% [markdown]
# ### Cantidad de establecimientos por tipo de actividad

# %%
df3 = guayaquil.dropna(subset=['ACTIVIDAD_ECONOMICA'])

# %%
len(df3['ACTIVIDAD_ECONOMICA'].unique())
# Out:
# 1626

# %%
top10 = df3.groupby('ACTIVIDAD_ECONOMICA').size().to_frame('cantidad').sort_values(['cantidad'], ascending=False).reset_index()[:11]
top10['ACTIVIDAD_ECONOMICA_MIN'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
top10['ACTIVIDAD_ECONOMICA'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:55], axis=1)

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN', data=top10,hue="ACTIVIDAD_ECONOMICA",palette=sns.color_palette("Set1", n_colors=10, desat=.5))
ax.set(ylabel='CANTIDAD DE ESTABLECIMIENTOS',xlabel="ACTIVIDAD ECONÓMICA", title='Cantidad de establecimientos por actividad ecónomica')
ax.set_xticklabels(labels=top10['ACTIVIDAD_ECONOMICA_MIN'],rotation=90)
top10["ACTIVIDAD_ECONOMICA"][:]
# Out:
# 0     ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...
# 1     VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...
# 2     RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...
# 3     OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...
# 4     INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...
# 5     INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, M...
# 6                                   SERVICIOS DE TAXIS.
# 7                        SIN ACTIVIDAD ECONOMICA - CIIU
# 8     OTRAS ACTIVIDADES DE CONTABILIDAD, TENEDURÍA D...
# 9     VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...
# 10    CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDEN...
# Name: ACTIVIDAD_ECONOMICA, dtype: object

# %% [markdown]
# ### Cantidad de contribuyentes por actividad

# %%
cont_act = df3[['ACTIVIDAD_ECONOMICA', 'NUMERO_RUC']].groupby(['ACTIVIDAD_ECONOMICA'])

# %%
top10_cont = cont_act['NUMERO_RUC'].nunique().to_frame('cantidad').sort_values('cantidad', ascending=False).reset_index()[:11]
top10_cont['ACTIVIDAD_ECONOMICA_MIN'] = top10_cont.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
top10_cont['ACTIVIDAD_ECONOMICA'] = top10_cont.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:50], axis=1)

# %%
top10_cont
# Out:
#                                   ACTIVIDAD_ECONOMICA  cantidad  \
# 0   ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEA...    113959
# 1   VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCT...     50560
# 2   OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y...     45966
# 3   RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETE...     44996
# 4   INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER ...     38971
# 5                      SIN ACTIVIDAD ECONOMICA - CIIU     25064
# 6   INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, M...     23174
# 7                                 SERVICIOS DE TAXIS.     23147
# 8   OTRAS ACTIVIDADES DE CONTABILIDAD, TENEDURÍA D...     18127
# 9   CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDEN...     16346
# 10  VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN E...     15367
#
#       ACTIVIDAD_ECONOMICA_MIN
# 0   ACTIVIDADES DE LIMPIABOTA
# 1   VENTA AL POR MENOR DE GRA
# 2   OTRAS ACTIVIDADES PROFESI
# 3   RESTAURANTES, CEVICHERÍAS
# 4   INTERMEDIACIÓN EN LA COMP
# 5   SIN ACTIVIDAD ECONOMICA -
# 6   INTERMEDIARIOS DEL COMERC
# 7         SERVICIOS DE TAXIS.
# 8   OTRAS ACTIVIDADES DE CONT
# 9   CONSTRUCCIÓN DE TODO TIPO
# 10  VENTA AL POR MAYOR DE DIV

# %%
plt.figure(figsize=(16, 6))
ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN', data=top10_cont,hue="ACTIVIDAD_ECONOMICA",palette=sns.color_palette("Set1", n_colors=10, desat=.5))
ax.set(ylabel='CANTIDAD DE CONTRIBUYENTES', title='Cantidad de contribuyentes por Actividad',xlabel="ACTIVIDAD ECÓNOMICA")
ax.set_xticklabels(labels=top10_cont['ACTIVIDAD_ECONOMICA'],rotation=90)
# Out:
# [Text(0, 0, 'ACTIVIDADES DE LIMPIABOTAS (BETUNEROS), PORTEADORE'),
#  Text(0, 0, 'VENTA AL POR MENOR DE GRAN VARIEDAD DE PRODUCTOS E'),
#  Text(0, 0, 'OTRAS ACTIVIDADES PROFESIONALES, CIENTÍFICAS Y TÉC'),
#  Text(0, 0, 'RESTAURANTES, CEVICHERÍAS, PICANTERÍAS, CAFETERÍAS'),
#  Text(0, 0, 'INTERMEDIACIÓN EN LA COMPRA, VENTA Y ALQUILER DE B'),
#  Text(0, 0, 'SIN ACTIVIDAD ECONOMICA - CIIU'),
#  Text(0, 0, 'INTERMEDIARIOS DEL COMERCIO DE COMBUSTIBLES, MINER'),
#  Text(0, 0, 'SERVICIOS DE TAXIS.'),
#  Text(0, 0, 'OTRAS ACTIVIDADES DE CONTABILIDAD, TENEDURÍA DE LI'),
#  Text(0, 0, 'CONSTRUCCIÓN DE TODO TIPO DE EDIFICIOS RESIDENCIAL'),
#  Text(0, 0, 'VENTA AL POR MAYOR DE DIVERSOS PRODUCTOS SIN ESPEC')]

# %%
df3 = df3.dropna(subset=['FECHA_INICIO_ACTIVIDADES'])
df3['FECHA_INICIO_ACTIVIDADES'] = pd.to_datetime(df3['FECHA_INICIO_ACTIVIDADES'])
df3['fecha_ano'] = df3['FECHA_INICIO_ACTIVIDADES'].dt.year
def mapper(month):
    return month.strftime('%b') 
df3['fecha_mes'] = df3['FECHA_INICIO_ACTIVIDADES'].apply(mapper)

# %%
lista_colores = sns.color_palette("muted", n_colors=20, desat=1)
palette = dict(zip(top10['ACTIVIDAD_ECONOMICA'].head(1),"blue"))
dic = []
def por_actividad_mes(ano):
    plt.figure(figsize=(26, 10))
    df_x = df3[df3['fecha_ano']==ano ]
    top10 = df_x.groupby('ACTIVIDAD_ECONOMICA').size().to_frame('cantidad').sort_values(['cantidad'], ascending=False).reset_index()[:5]
    top10['ACTIVIDAD_ECONOMICA'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:55], axis=1)
    top10['ACTIVIDAD_ECONOMICA_MIN'] = top10.apply(lambda row: row['ACTIVIDAD_ECONOMICA'][:25], axis=1)
    for actividad in top10['ACTIVIDAD_ECONOMICA']:
        if actividad not in dic:
            dic.append(actividad)
            palette.update({actividad:lista_colores.pop()})
    ax = sns.barplot(y='cantidad', x='ACTIVIDAD_ECONOMICA_MIN',ci=None, data=top10,hue="ACTIVIDAD_ECONOMICA",palette=palette)
    ax.set(ylabel='CANTIDAD DE ESTABLECIMIENTOS',xlabel="ACTIVIDAD ECONÓMICA", title='Cantidad de establecimientos por actividad ecónomica '+ str(ano),ylim=(0, 16000))
    ax.set_xticklabels(labels=top10['ACTIVIDAD_ECONOMICA_MIN'],rotation=90)
    plt.savefig("CONTRIBUYENTES_X_ANO_"+str(ano)+".png")
df3 = df3[ (1998 <=df3['fecha_ano']) & (df3['fecha_ano']<=2018)]
for ano in df3['fecha_ano'].unique().tolist():
    por_actividad_mes(ano)
#convert -delay 30 *.png establecimiento_actividad_ano.gif
len(lista_colores)
# Out:
# /media/mdleiton/Respaldo/repositorios/AED/env/lib/python3.5/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 6
